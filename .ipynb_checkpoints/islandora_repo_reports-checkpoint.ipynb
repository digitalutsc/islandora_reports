# %%
import numpy as np
import pandas as pd

# %%
def get_namespace(column_value):
    column_value_list = column_value.split(":")
    return column_value_list[0]

# %%
def count_checksums(checksum_column):
    if checksum_column == "not_set":
        return 0
    else:
        checksum_list = checksum_column.split(",")
        return len(checksum_list)

# %%
def get_members(df, df_collection_members, collection, b_include_pages):
    is_collection_member =  df['isMemberOfCollection'] == collection
    member_list = df[is_collection_member]
    
    if b_include_pages == True:
        is_part_of_book =  df['isPageOf'] == collection
        member_list_pages = df[is_part_of_book]
        member_list = member_list.append(member_list_pages,ignore_index=True)
        
    ## Loop through each member, if it is a collection model, then call this again!
    for index, row in member_list.iterrows():
        pid = row["PID"]
        cmodel = row["cmodel"]
        is_member_of_collection = row["isMemberOfCollection"]
        if cmodel == "info:fedora/islandora:collectionCModel" or cmodel == "info:fedora/islandora:bookCModel":
            df_collection_members = get_members(df, df_collection_members, "info:fedora/"+pid, b_include_pages)
        
    df_collection_members = df_collection_members.append(member_list,ignore_index=True)
    return df_collection_members

# %%
df = pd.read_csv("data/repo_data.csv") 
df.checksum_list = df.checksum_list.fillna('not_set')
df['checksum_count'] = df.apply(lambda x: count_checksums(x['checksum_list']), axis=1)
df
# Out:
#                                     PID  \
# 0                          islandora:11
# 1                          islandora:10
# 2                             example:3
# 3                             example:2
# 4                           islandora:8
# 5                           islandora:6
# 6                           islandora:5
# 7                           islandora:2
# 8                           islandora:1
# 9                             example:4
# 10                          example:nat
# 11                            example:1
# 12                     utsc:collection2
# 13  islandora:sp_basic_image_collection
# 14                ir:citationCollection
# 15  islandora:sp_web_archive_collection
# 16           islandora:video_collection
# 17          islandora:sp_pdf_collection
# 18       islandora:newspaper_collection
# 19  islandora:sp_large_image_collection
# 20          islandora:entity_collection
# 21   islandora:sp_disk_image_collection
# 22        islandora:compound_collection
# 23             islandora:bookCollection
# 24           islandora:audio_collection
# 25                       islandora:root
#
#                                isMemberOfCollection               isPageOf  \
# 0                           info:fedora/example:nat                    NaN
# 1                           info:fedora/example:nat                    NaN
# 2                                               NaN  info:fedora/example:1
# 3                                               NaN  info:fedora/example:1
# 4                      info:fedora/utsc:collection2                    NaN
# 5                           info:fedora/example:nat                    NaN
# 6                           info:fedora/example:nat                    NaN
# 7   info:fedora/islandora:sp_basic_image_collection                    NaN
# 8   info:fedora/islandora:sp_basic_image_collection                    NaN
# 9                           info:fedora/example:nat                    NaN
# 10  info:fedora/islandora:sp_basic_image_collection                    NaN
# 11                          info:fedora/example:nat                    NaN
# 12                          info:fedora/example:nat                    NaN
# 13                       info:fedora/islandora:root                    NaN
# 14                       info:fedora/islandora:root                    NaN
# 15                       info:fedora/islandora:root                    NaN
# 16                       info:fedora/islandora:root                    NaN
# 17                       info:fedora/islandora:root                    NaN
# 18                       info:fedora/islandora:root                    NaN
# 19                       info:fedora/islandora:root                    NaN
# 20                       info:fedora/islandora:root                    NaN
# 21                       info:fedora/islandora:root                    NaN
# 22                       info:fedora/islandora:root                    NaN
# 23                       info:fedora/islandora:root                    NaN
# 24                       info:fedora/islandora:root                    NaN
# 25                                              NaN                    NaN
#
#                                     cmodel  \
# 0     info:fedora/islandora:sp_basic_image
# 1     info:fedora/islandora:sp_basic_image
# 2         info:fedora/islandora:pageCModel
# 3         info:fedora/islandora:pageCModel
# 4     info:fedora/islandora:sp_basic_image
# 5     info:fedora/islandora:sp_basic_image
# 6     info:fedora/islandora:sp_basic_image
# 7     info:fedora/islandora:sp_basic_image
# 8     info:fedora/islandora:sp_basic_image
# 9     info:fedora/islandora:compoundCModel
# 10  info:fedora/islandora:collectionCModel
# 11        info:fedora/islandora:bookCModel
# 12  info:fedora/islandora:collectionCModel
# 13  info:fedora/islandora:collectionCModel
# 14  info:fedora/islandora:collectionCModel
# 15  info:fedora/islandora:collectionCModel
# 16  info:fedora/islandora:collectionCModel
# 17  info:fedora/islandora:collectionCModel
# 18  info:fedora/islandora:collectionCModel
# 19  info:fedora/islandora:collectionCModel
# 20  info:fedora/islandora:collectionCModel
# 21  info:fedora/islandora:collectionCModel
# 22  info:fedora/islandora:collectionCModel
# 23  info:fedora/islandora:collectionCModel
# 24  info:fedora/islandora:collectionCModel
# 25  info:fedora/islandora:collectionCModel
#
#                                       datastream_list  datastreams_count  \
# 0   AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 1   AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 2   AUDIT, RELS-EXT, PDF, OBJ, DC, TN, JP2, TECHMD...                 10
# 3   AUDIT, RELS-EXT, PDF, OBJ, DC, TN, JP2, TECHMD...                 10
# 4   AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 5   AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 6   AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 7   AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 8   AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 9                       AUDIT, RELS-EXT, MODS, DC, TN                  5
# 10   AUDIT, RELS-EXT, COLLECTION_POLICY, MODS, DC, TN                  6
# 11                 AUDIT, RELS-EXT, MODS, DC, PDF, TN                  6
# 12   AUDIT, RELS-EXT, COLLECTION_POLICY, MODS, DC, TN                  6
# 13         AUDIT, RELS-EXT, COLLECTION_POLICY, TN, DC                  5
# 14                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 15                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 16                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 17                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 18                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 19                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 20                RELS-EXT, TN, COLLECTION_POLICY, DC                  4
# 21                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 22                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 23                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 24                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 25                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
#
#    OBJ_Exists                              obj_checksum  \
# 0         OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 1         OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 2         OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 3         OBJ  cd3b241ed4869776bb90387b51766e04b7a62151
# 4         OBJ  f4e806111bdb1c39c1e281e342afd59fed40d198
# 5         OBJ  4784c50df21ca2fa8f2a3219adcaf9dbbffe7ae8
# 6         OBJ  4e424da322f285aa179caec35397d161ab76c075
# 7         OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 8         OBJ  f4e806111bdb1c39c1e281e342afd59fed40d198
# 9          NO                                   not_set
# 10         NO                                   not_set
# 11         NO                                   not_set
# 12         NO                                   not_set
# 13         NO                                   not_set
# 14         NO                                   not_set
# 15         NO                                   not_set
# 16         NO                                   not_set
# 17         NO                                   not_set
# 18         NO                                   not_set
# 19         NO                                   not_set
# 20         NO                                   not_set
# 21         NO                                   not_set
# 22         NO                                   not_set
# 23         NO                                   not_set
# 24         NO                                   not_set
# 25         NO                                   not_set
#
#                                         checksum_list   Premis_Check  \
# 0   not_set, 94e8f30a05c70096e53be5b1dcb6066769dbb...      Validated
# 1   not_set, d1c419dba0ca9e133dcdd478ad654b728e1f7...      Validated
# 2   not_set, 3092d6667f455f236e48a737b1cbd12cbe17a...      Validated
# 3   not_set, 0b34e4584546dc42ef0f0209ca1105ce87cc7...      Validated
# 4   not_set, 8a77ac9ee1a9edca8183cd33525a5759bc2ff...      Validated
# 5   not_set, a4eeb4470e100b73ee58662ba364fac89e9bb...      Validated
# 6   not_set, 6c11a823b8451a7f9b1ffc417d981ea2a2f0d...      Validated
# 7   not_set, ea79b5308c79d6029df65087a17f741435636...      Validated
# 8   not_set, 0f26c9457abf726f8be9d82ff26c19ccb27a9...      Validated
# 9   not_set, 3395fd1108c111ef44d32e22fdf408c0d52b3...  Not Validated
# 10  not_set, 4ce44ed90a367badf13625d5a7cdae8d40d8d...  Not Validated
# 11  not_set, c065002845edb766ef0ed320af6edb8a84767...  Not Validated
# 12  not_set, 94e0e6bc570b041b741db5e466da7ebac42e8...  Not Validated
# 13        not_set, not_set, not_set, not_set, not_set  Not Validated
# 14                 not_set, not_set, not_set, not_set  Not Validated
# 15                 not_set, not_set, not_set, not_set  Not Validated
# 16                 not_set, not_set, not_set, not_set  Not Validated
# 17                 not_set, not_set, not_set, not_set  Not Validated
# 18                 not_set, not_set, not_set, not_set  Not Validated
# 19                 not_set, not_set, not_set, not_set  Not Validated
# 20                 not_set, not_set, not_set, not_set  Not Validated
# 21                 not_set, not_set, not_set, not_set  Not Validated
# 22                 not_set, not_set, not_set, not_set  Not Validated
# 23                 not_set, not_set, not_set, not_set  Not Validated
# 24                 not_set, not_set, not_set, not_set  Not Validated
# 25                 not_set, not_set, not_set, not_set  Not Validated
#
#    Last_Modified_By                               obj_format  \
# 0             admin  JPEG File Interchange Format, JPEG EXIF
# 1             admin  JPEG File Interchange Format, JPEG EXIF
# 2             admin                                TIFF EXIF
# 3             admin                                TIFF EXIF
# 4             admin                                JPEG EXIF
# 5             admin                                JPEG EXIF
# 6             admin                                JPEG EXIF
# 7             admin  JPEG File Interchange Format, JPEG EXIF
# 8             admin                                JPEG EXIF
# 9             admin                                      NaN
# 10            admin                                      NaN
# 11            admin                                      NaN
# 12            admin                                      NaN
# 13            admin                                      NaN
# 14              NaN                                      NaN
# 15              NaN                                      NaN
# 16              NaN                                      NaN
# 17              NaN                                      NaN
# 18              NaN                                      NaN
# 19              NaN                                      NaN
# 20              NaN                                      NaN
# 21              NaN                                      NaN
# 22              NaN                                      NaN
# 23              NaN                                      NaN
# 24              NaN                                      NaN
# 25              NaN                                      NaN
#
#                                        mimetypes_list                   title  \
# 0   text/xml, application/rdf+xml, application/xml...             second page
# 1   text/xml, application/rdf+xml, application/xml...               back page
# 2   text/xml, application/rdf+xml, application/pdf...            sample.pdf-2
# 3   text/xml, application/rdf+xml, application/pdf...            sample.pdf-1
# 4   text/xml, application/rdf+xml, application/xml...                    aaaa
# 5   text/xml, application/rdf+xml, application/xml...         inside object 2
# 6   text/xml, application/rdf+xml, application/xml...         inside object 1
# 7   text/xml, application/rdf+xml, application/xml...                   22222
# 8   text/xml, application/rdf+xml, application/xml...             88888888888
# 9   text/xml, application/rdf+xml, application/xml...                   front
# 10  text/xml, application/rdf+xml, text/xml, appli...             example:nat
# 11  text/xml, application/rdf+xml, application/xml...             sample book
# 12  text/xml, application/rdf+xml, text/xml, appli...         utsc colleciton
# 13  text/xml, application/rdf+xml, application/xml...  Basic Image Collection
# 14  application/rdf+xml, text/xml, image/png, text...               Citations
# 15  application/rdf+xml, application/xml, image/pn...  Web ARChive Collection
# 16  application/rdf+xml, application/xml, image/pn...        Video Collection
# 17  application/rdf+xml, application/xml, image/pn...          PDF Collection
# 18  application/rdf+xml, application/xml, image/pn...    Newspaper Collection
# 19  application/rdf+xml, application/xml, image/pn...  Large Image Collection
# 20  application/rdf+xml, image/png, text/xml, text...       Entity Collection
# 21  application/rdf+xml, application/xml, image/pn...   Disk Image Collection
# 22  application/rdf+xml, application/xml, image/pn...     Compound Collection
# 23  application/rdf+xml, application/xml, image/pn...         Book Collection
# 24  application/rdf+xml, application/xml, image/pn...        Audio Collection
# 25  application/rdf+xml, application/xml, image/pn...    Top-level Collection
#
#                                             size_list  \
# 0   not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 1   not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 2   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 3   not_set, 822, 6185, 298854, 374, 189257, 14929...
# 4   not_set, 546, 1253, 446, 3773963, 11028, 29019...
# 5   not_set, 541, 1264, 457, 9041285, 10422, 70911...
# 6   not_set, 541, 1264, 457, 9240579, 10422, 71002...
# 7   not_set, 565, 1254, 447, 1878576, 3440, 29414,...
# 8   not_set, 565, 1505, 495, 3773963, 11029, 29019...
# 9                       not_set, 539, 856, 425, 29414
# 10                  not_set, 567, 927, 406, 435, 5137
# 11              not_set, 535, 1439, 399, 3028, 189257
# 12                  not_set, 548, 641, 410, 444, 5137
# 13                      not_set2, 570, 582, 5137, 410
# 14                                570, 644, 5137, 382
# 15                                584, 531, 5137, 409
# 16                                575, 519, 5137, 394
# 17                                576, 642, 5137, 393
# 18                                579, 690, 5137, 402
# 19                                584, 535, 5137, 409
# 20                                576, 5137, 936, 396
# 21                                583, 528, 5137, 407
# 22                                578, 726, 5137, 400
# 23                               573, 1165, 5137, 391
# 24                                575, 510, 5137, 394
# 25                               457, 1209, 5137, 386
#
#              fgs_lastModifiedDate_dt  checksum_count
# 0    Tuesday, March 26, 2019 - 01:05               8
# 1    Tuesday, March 26, 2019 - 01:05               8
# 2    Tuesday, March 26, 2019 - 01:05              10
# 3    Tuesday, March 26, 2019 - 01:05              10
# 4    Tuesday, March 26, 2019 - 01:05               8
# 5    Tuesday, March 26, 2019 - 01:05               8
# 6    Tuesday, March 26, 2019 - 01:05               8
# 7    Tuesday, March 26, 2019 - 01:05               8
# 8    Tuesday, March 26, 2019 - 01:05               8
# 9     Monday, March 25, 2019 - 19:58               5
# 10    Monday, March 25, 2019 - 19:55               6
# 11    Monday, March 25, 2019 - 19:43               6
# 12    Monday, March 25, 2019 - 19:31               6
# 13  Thursday, March 21, 2019 - 16:43               5
# 14  Thursday, March 21, 2019 - 16:22               4
# 15  Thursday, March 21, 2019 - 16:22               4
# 16  Thursday, March 21, 2019 - 16:22               4
# 17  Thursday, March 21, 2019 - 16:22               4
# 18  Thursday, March 21, 2019 - 16:22               4
# 19  Thursday, March 21, 2019 - 16:22               4
# 20  Thursday, March 21, 2019 - 16:22               4
# 21  Thursday, March 21, 2019 - 16:22               4
# 22  Thursday, March 21, 2019 - 16:22               4
# 23  Thursday, March 21, 2019 - 16:22               4
# 24  Thursday, March 21, 2019 - 16:22               4
# 25  Thursday, March 21, 2019 - 16:22               4

# %% [markdown]
# ## Namespace Info

# %%
# Objects by namespace
df['namespace'] = df.apply(lambda x: get_namespace(x['PID']), axis=1)
df_namespace = df.groupby('namespace')["PID"].count().reset_index(name="count")

# %%
df_namespace.to_csv("reports/objets_by_namespace.csv")

# %% [markdown]
# ## Collections info

# %%
collection = "info:fedora/islandora:sp_basic_image_collection"
collection_info = collection.split(":")
collection_name = collection_info[2]
collection_name
# Out:
# 'sp_basic_image_collection'

# %%
# List of conceptual objects (includes objects that are part of compound model)
# For compound objects, Hide child objects in Solr results  should be turned off
df_collection_members = pd.DataFrame()
df_collection_members = get_members(df, df_collection_members, collection, False)
df_collection_members
# Out:
#                  PID                             isMemberOfCollection  \
# 0        islandora:8                     info:fedora/utsc:collection2
# 1       islandora:11                          info:fedora/example:nat
# 2       islandora:10                          info:fedora/example:nat
# 3        islandora:6                          info:fedora/example:nat
# 4        islandora:5                          info:fedora/example:nat
# 5          example:4                          info:fedora/example:nat
# 6          example:1                          info:fedora/example:nat
# 7   utsc:collection2                          info:fedora/example:nat
# 8        islandora:2  info:fedora/islandora:sp_basic_image_collection
# 9        islandora:1  info:fedora/islandora:sp_basic_image_collection
# 10       example:nat  info:fedora/islandora:sp_basic_image_collection
#
#    isPageOf                                  cmodel  \
# 0       NaN    info:fedora/islandora:sp_basic_image
# 1       NaN    info:fedora/islandora:sp_basic_image
# 2       NaN    info:fedora/islandora:sp_basic_image
# 3       NaN    info:fedora/islandora:sp_basic_image
# 4       NaN    info:fedora/islandora:sp_basic_image
# 5       NaN    info:fedora/islandora:compoundCModel
# 6       NaN        info:fedora/islandora:bookCModel
# 7       NaN  info:fedora/islandora:collectionCModel
# 8       NaN    info:fedora/islandora:sp_basic_image
# 9       NaN    info:fedora/islandora:sp_basic_image
# 10      NaN  info:fedora/islandora:collectionCModel
#
#                                       datastream_list  datastreams_count  \
# 0   AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 1   AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 2   AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 3   AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 4   AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 5                       AUDIT, RELS-EXT, MODS, DC, TN                  5
# 6                  AUDIT, RELS-EXT, MODS, DC, PDF, TN                  6
# 7    AUDIT, RELS-EXT, COLLECTION_POLICY, MODS, DC, TN                  6
# 8   AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 9   AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 10   AUDIT, RELS-EXT, COLLECTION_POLICY, MODS, DC, TN                  6
#
#    OBJ_Exists                              obj_checksum  \
# 0         OBJ  f4e806111bdb1c39c1e281e342afd59fed40d198
# 1         OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 2         OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 3         OBJ  4784c50df21ca2fa8f2a3219adcaf9dbbffe7ae8
# 4         OBJ  4e424da322f285aa179caec35397d161ab76c075
# 5          NO                                   not_set
# 6          NO                                   not_set
# 7          NO                                   not_set
# 8         OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 9         OBJ  f4e806111bdb1c39c1e281e342afd59fed40d198
# 10         NO                                   not_set
#
#                                         checksum_list   Premis_Check  \
# 0   not_set, 8a77ac9ee1a9edca8183cd33525a5759bc2ff...      Validated
# 1   not_set, 94e8f30a05c70096e53be5b1dcb6066769dbb...      Validated
# 2   not_set, d1c419dba0ca9e133dcdd478ad654b728e1f7...      Validated
# 3   not_set, a4eeb4470e100b73ee58662ba364fac89e9bb...      Validated
# 4   not_set, 6c11a823b8451a7f9b1ffc417d981ea2a2f0d...      Validated
# 5   not_set, 3395fd1108c111ef44d32e22fdf408c0d52b3...  Not Validated
# 6   not_set, c065002845edb766ef0ed320af6edb8a84767...  Not Validated
# 7   not_set, 94e0e6bc570b041b741db5e466da7ebac42e8...  Not Validated
# 8   not_set, ea79b5308c79d6029df65087a17f741435636...      Validated
# 9   not_set, 0f26c9457abf726f8be9d82ff26c19ccb27a9...      Validated
# 10  not_set, 4ce44ed90a367badf13625d5a7cdae8d40d8d...  Not Validated
#
#    Last_Modified_By                               obj_format  \
# 0             admin                                JPEG EXIF
# 1             admin  JPEG File Interchange Format, JPEG EXIF
# 2             admin  JPEG File Interchange Format, JPEG EXIF
# 3             admin                                JPEG EXIF
# 4             admin                                JPEG EXIF
# 5             admin                                      NaN
# 6             admin                                      NaN
# 7             admin                                      NaN
# 8             admin  JPEG File Interchange Format, JPEG EXIF
# 9             admin                                JPEG EXIF
# 10            admin                                      NaN
#
#                                        mimetypes_list            title  \
# 0   text/xml, application/rdf+xml, application/xml...             aaaa
# 1   text/xml, application/rdf+xml, application/xml...      second page
# 2   text/xml, application/rdf+xml, application/xml...        back page
# 3   text/xml, application/rdf+xml, application/xml...  inside object 2
# 4   text/xml, application/rdf+xml, application/xml...  inside object 1
# 5   text/xml, application/rdf+xml, application/xml...            front
# 6   text/xml, application/rdf+xml, application/xml...      sample book
# 7   text/xml, application/rdf+xml, text/xml, appli...  utsc colleciton
# 8   text/xml, application/rdf+xml, application/xml...            22222
# 9   text/xml, application/rdf+xml, application/xml...      88888888888
# 10  text/xml, application/rdf+xml, text/xml, appli...      example:nat
#
#                                             size_list  \
# 0   not_set, 546, 1253, 446, 3773963, 11028, 29019...
# 1   not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 2   not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 3   not_set, 541, 1264, 457, 9041285, 10422, 70911...
# 4   not_set, 541, 1264, 457, 9240579, 10422, 71002...
# 5                       not_set, 539, 856, 425, 29414
# 6               not_set, 535, 1439, 399, 3028, 189257
# 7                   not_set, 548, 641, 410, 444, 5137
# 8   not_set, 565, 1254, 447, 1878576, 3440, 29414,...
# 9   not_set, 565, 1505, 495, 3773963, 11029, 29019...
# 10                  not_set, 567, 927, 406, 435, 5137
#
#             fgs_lastModifiedDate_dt  checksum_count  namespace
# 0   Tuesday, March 26, 2019 - 01:05               8  islandora
# 1   Tuesday, March 26, 2019 - 01:05               8  islandora
# 2   Tuesday, March 26, 2019 - 01:05               8  islandora
# 3   Tuesday, March 26, 2019 - 01:05               8  islandora
# 4   Tuesday, March 26, 2019 - 01:05               8  islandora
# 5    Monday, March 25, 2019 - 19:58               5    example
# 6    Monday, March 25, 2019 - 19:43               6    example
# 7    Monday, March 25, 2019 - 19:31               6       utsc
# 8   Tuesday, March 26, 2019 - 01:05               8  islandora
# 9   Tuesday, March 26, 2019 - 01:05               8  islandora
# 10   Monday, March 25, 2019 - 19:55               6    example

# %%
df_collection_members.to_csv("reports/objects_by_collections_" + collection_name + ".csv")

# %%
# List of objects (including pages)
df_collection_members = pd.DataFrame()
df_collection_members = get_members(df, df_collection_members, collection, True)
df_collection_members.head(5)
# Out:
#             PID          isMemberOfCollection               isPageOf  \
# 0     example:3                           NaN  info:fedora/example:1
# 1     example:2                           NaN  info:fedora/example:1
# 2   islandora:8  info:fedora/utsc:collection2                    NaN
# 3  islandora:11       info:fedora/example:nat                    NaN
# 4  islandora:10       info:fedora/example:nat                    NaN
#
#                                  cmodel  \
# 0      info:fedora/islandora:pageCModel
# 1      info:fedora/islandora:pageCModel
# 2  info:fedora/islandora:sp_basic_image
# 3  info:fedora/islandora:sp_basic_image
# 4  info:fedora/islandora:sp_basic_image
#
#                                      datastream_list  datastreams_count  \
# 0  AUDIT, RELS-EXT, PDF, OBJ, DC, TN, JP2, TECHMD...                 10
# 1  AUDIT, RELS-EXT, PDF, OBJ, DC, TN, JP2, TECHMD...                 10
# 2  AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 3  AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 4  AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
#
#   OBJ_Exists                              obj_checksum  \
# 0        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 1        OBJ  cd3b241ed4869776bb90387b51766e04b7a62151
# 2        OBJ  f4e806111bdb1c39c1e281e342afd59fed40d198
# 3        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 4        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
#
#                                        checksum_list Premis_Check  \
# 0  not_set, 3092d6667f455f236e48a737b1cbd12cbe17a...    Validated
# 1  not_set, 0b34e4584546dc42ef0f0209ca1105ce87cc7...    Validated
# 2  not_set, 8a77ac9ee1a9edca8183cd33525a5759bc2ff...    Validated
# 3  not_set, 94e8f30a05c70096e53be5b1dcb6066769dbb...    Validated
# 4  not_set, d1c419dba0ca9e133dcdd478ad654b728e1f7...    Validated
#
#   Last_Modified_By                               obj_format  \
# 0            admin                                TIFF EXIF
# 1            admin                                TIFF EXIF
# 2            admin                                JPEG EXIF
# 3            admin  JPEG File Interchange Format, JPEG EXIF
# 4            admin  JPEG File Interchange Format, JPEG EXIF
#
#                                       mimetypes_list         title  \
# 0  text/xml, application/rdf+xml, application/pdf...  sample.pdf-2
# 1  text/xml, application/rdf+xml, application/pdf...  sample.pdf-1
# 2  text/xml, application/rdf+xml, application/xml...          aaaa
# 3  text/xml, application/rdf+xml, application/xml...   second page
# 4  text/xml, application/rdf+xml, application/xml...     back page
#
#                                            size_list  \
# 0  not_set, 822, 6636, 280983, 374, 188825, 13813...
# 1  not_set, 822, 6185, 298854, 374, 189257, 14929...
# 2  not_set, 546, 1253, 446, 3773963, 11028, 29019...
# 3  not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 4  not_set, 718, 1258, 452, 1878576, 3439, 29414,...
#
#            fgs_lastModifiedDate_dt  checksum_count  namespace
# 0  Tuesday, March 26, 2019 - 01:05              10    example
# 1  Tuesday, March 26, 2019 - 01:05              10    example
# 2  Tuesday, March 26, 2019 - 01:05               8  islandora
# 3  Tuesday, March 26, 2019 - 01:05               8  islandora
# 4  Tuesday, March 26, 2019 - 01:05               8  islandora

# %%
df_collection_members.to_csv("reports/objects_by_collections_" + collection_name + "_including_pages.csv")

# %% [markdown]
# ## Datastream Info

# %%
#https://riptutorial.com/pandas/example/25462/split--reshape--csv-strings-in-columns-into-multiple-rows--having-one-element-per-row
df_ds = \
(df.set_index(df.columns.drop('datastream_list',1).tolist())
   .datastream_list.str.split(',', expand=True)
   .stack()
   .reset_index()
   .rename(columns={0:'datastream_list'})
   .loc[:, df.columns]
)
df_ds.rename(columns={'datastream_list':'datastream'}, inplace=True)
del df_ds["datastreams_count"]
df_ds
# Out:
#                                      PID        isMemberOfCollection  \
# 0                           islandora:11     info:fedora/example:nat
# 1                           islandora:11     info:fedora/example:nat
# 2                           islandora:11     info:fedora/example:nat
# 3                           islandora:11     info:fedora/example:nat
# 4                           islandora:11     info:fedora/example:nat
# 5                           islandora:11     info:fedora/example:nat
# 6                           islandora:11     info:fedora/example:nat
# 7                           islandora:11     info:fedora/example:nat
# 8                           islandora:10     info:fedora/example:nat
# 9                           islandora:10     info:fedora/example:nat
# 10                          islandora:10     info:fedora/example:nat
# 11                          islandora:10     info:fedora/example:nat
# 12                          islandora:10     info:fedora/example:nat
# 13                          islandora:10     info:fedora/example:nat
# 14                          islandora:10     info:fedora/example:nat
# 15                          islandora:10     info:fedora/example:nat
# 16                             example:3                         NaN
# 17                             example:3                         NaN
# 18                             example:3                         NaN
# 19                             example:3                         NaN
# 20                             example:3                         NaN
# 21                             example:3                         NaN
# 22                             example:3                         NaN
# 23                             example:3                         NaN
# 24                             example:3                         NaN
# 25                             example:3                         NaN
# 26                             example:2                         NaN
# 27                             example:2                         NaN
# 28                             example:2                         NaN
# 29                             example:2                         NaN
# ..                                   ...                         ...
# 122       islandora:newspaper_collection  info:fedora/islandora:root
# 123       islandora:newspaper_collection  info:fedora/islandora:root
# 124  islandora:sp_large_image_collection  info:fedora/islandora:root
# 125  islandora:sp_large_image_collection  info:fedora/islandora:root
# 126  islandora:sp_large_image_collection  info:fedora/islandora:root
# 127  islandora:sp_large_image_collection  info:fedora/islandora:root
# 128          islandora:entity_collection  info:fedora/islandora:root
# 129          islandora:entity_collection  info:fedora/islandora:root
# 130          islandora:entity_collection  info:fedora/islandora:root
# 131          islandora:entity_collection  info:fedora/islandora:root
# 132   islandora:sp_disk_image_collection  info:fedora/islandora:root
# 133   islandora:sp_disk_image_collection  info:fedora/islandora:root
# 134   islandora:sp_disk_image_collection  info:fedora/islandora:root
# 135   islandora:sp_disk_image_collection  info:fedora/islandora:root
# 136        islandora:compound_collection  info:fedora/islandora:root
# 137        islandora:compound_collection  info:fedora/islandora:root
# 138        islandora:compound_collection  info:fedora/islandora:root
# 139        islandora:compound_collection  info:fedora/islandora:root
# 140             islandora:bookCollection  info:fedora/islandora:root
# 141             islandora:bookCollection  info:fedora/islandora:root
# 142             islandora:bookCollection  info:fedora/islandora:root
# 143             islandora:bookCollection  info:fedora/islandora:root
# 144           islandora:audio_collection  info:fedora/islandora:root
# 145           islandora:audio_collection  info:fedora/islandora:root
# 146           islandora:audio_collection  info:fedora/islandora:root
# 147           islandora:audio_collection  info:fedora/islandora:root
# 148                       islandora:root                         NaN
# 149                       islandora:root                         NaN
# 150                       islandora:root                         NaN
# 151                       islandora:root                         NaN
#
#                   isPageOf                                  cmodel  \
# 0                      NaN    info:fedora/islandora:sp_basic_image
# 1                      NaN    info:fedora/islandora:sp_basic_image
# 2                      NaN    info:fedora/islandora:sp_basic_image
# 3                      NaN    info:fedora/islandora:sp_basic_image
# 4                      NaN    info:fedora/islandora:sp_basic_image
# 5                      NaN    info:fedora/islandora:sp_basic_image
# 6                      NaN    info:fedora/islandora:sp_basic_image
# 7                      NaN    info:fedora/islandora:sp_basic_image
# 8                      NaN    info:fedora/islandora:sp_basic_image
# 9                      NaN    info:fedora/islandora:sp_basic_image
# 10                     NaN    info:fedora/islandora:sp_basic_image
# 11                     NaN    info:fedora/islandora:sp_basic_image
# 12                     NaN    info:fedora/islandora:sp_basic_image
# 13                     NaN    info:fedora/islandora:sp_basic_image
# 14                     NaN    info:fedora/islandora:sp_basic_image
# 15                     NaN    info:fedora/islandora:sp_basic_image
# 16   info:fedora/example:1        info:fedora/islandora:pageCModel
# 17   info:fedora/example:1        info:fedora/islandora:pageCModel
# 18   info:fedora/example:1        info:fedora/islandora:pageCModel
# 19   info:fedora/example:1        info:fedora/islandora:pageCModel
# 20   info:fedora/example:1        info:fedora/islandora:pageCModel
# 21   info:fedora/example:1        info:fedora/islandora:pageCModel
# 22   info:fedora/example:1        info:fedora/islandora:pageCModel
# 23   info:fedora/example:1        info:fedora/islandora:pageCModel
# 24   info:fedora/example:1        info:fedora/islandora:pageCModel
# 25   info:fedora/example:1        info:fedora/islandora:pageCModel
# 26   info:fedora/example:1        info:fedora/islandora:pageCModel
# 27   info:fedora/example:1        info:fedora/islandora:pageCModel
# 28   info:fedora/example:1        info:fedora/islandora:pageCModel
# 29   info:fedora/example:1        info:fedora/islandora:pageCModel
# ..                     ...                                     ...
# 122                    NaN  info:fedora/islandora:collectionCModel
# 123                    NaN  info:fedora/islandora:collectionCModel
# 124                    NaN  info:fedora/islandora:collectionCModel
# 125                    NaN  info:fedora/islandora:collectionCModel
# 126                    NaN  info:fedora/islandora:collectionCModel
# 127                    NaN  info:fedora/islandora:collectionCModel
# 128                    NaN  info:fedora/islandora:collectionCModel
# 129                    NaN  info:fedora/islandora:collectionCModel
# 130                    NaN  info:fedora/islandora:collectionCModel
# 131                    NaN  info:fedora/islandora:collectionCModel
# 132                    NaN  info:fedora/islandora:collectionCModel
# 133                    NaN  info:fedora/islandora:collectionCModel
# 134                    NaN  info:fedora/islandora:collectionCModel
# 135                    NaN  info:fedora/islandora:collectionCModel
# 136                    NaN  info:fedora/islandora:collectionCModel
# 137                    NaN  info:fedora/islandora:collectionCModel
# 138                    NaN  info:fedora/islandora:collectionCModel
# 139                    NaN  info:fedora/islandora:collectionCModel
# 140                    NaN  info:fedora/islandora:collectionCModel
# 141                    NaN  info:fedora/islandora:collectionCModel
# 142                    NaN  info:fedora/islandora:collectionCModel
# 143                    NaN  info:fedora/islandora:collectionCModel
# 144                    NaN  info:fedora/islandora:collectionCModel
# 145                    NaN  info:fedora/islandora:collectionCModel
# 146                    NaN  info:fedora/islandora:collectionCModel
# 147                    NaN  info:fedora/islandora:collectionCModel
# 148                    NaN  info:fedora/islandora:collectionCModel
# 149                    NaN  info:fedora/islandora:collectionCModel
# 150                    NaN  info:fedora/islandora:collectionCModel
# 151                    NaN  info:fedora/islandora:collectionCModel
#
#              datastream OBJ_Exists                              obj_checksum  \
# 0                 AUDIT        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 1              RELS-EXT        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 2                  MODS        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 3                    DC        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 4                   OBJ        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 5                TECHMD        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 6                    TN        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 7           MEDIUM_SIZE        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 8                 AUDIT        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 9              RELS-EXT        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 10                 MODS        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 11                   DC        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 12                  OBJ        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 13               TECHMD        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 14                   TN        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 15          MEDIUM_SIZE        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 16                AUDIT        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 17             RELS-EXT        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 18                  PDF        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 19                  OBJ        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 20                   DC        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 21                   TN        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 22                  JP2        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 23               TECHMD        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 24                  JPG        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 25             RELS-INT        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 26                AUDIT        OBJ  cd3b241ed4869776bb90387b51766e04b7a62151
# 27             RELS-EXT        OBJ  cd3b241ed4869776bb90387b51766e04b7a62151
# 28                  PDF        OBJ  cd3b241ed4869776bb90387b51766e04b7a62151
# 29                  OBJ        OBJ  cd3b241ed4869776bb90387b51766e04b7a62151
# ..                  ...        ...                                       ...
# 122                  TN         NO                                   not_set
# 123                  DC         NO                                   not_set
# 124            RELS-EXT         NO                                   not_set
# 125   COLLECTION_POLICY         NO                                   not_set
# 126                  TN         NO                                   not_set
# 127                  DC         NO                                   not_set
# 128            RELS-EXT         NO                                   not_set
# 129                  TN         NO                                   not_set
# 130   COLLECTION_POLICY         NO                                   not_set
# 131                  DC         NO                                   not_set
# 132            RELS-EXT         NO                                   not_set
# 133   COLLECTION_POLICY         NO                                   not_set
# 134                  TN         NO                                   not_set
# 135                  DC         NO                                   not_set
# 136            RELS-EXT         NO                                   not_set
# 137   COLLECTION_POLICY         NO                                   not_set
# 138                  TN         NO                                   not_set
# 139                  DC         NO                                   not_set
# 140            RELS-EXT         NO                                   not_set
# 141   COLLECTION_POLICY         NO                                   not_set
# 142                  TN         NO                                   not_set
# 143                  DC         NO                                   not_set
# 144            RELS-EXT         NO                                   not_set
# 145   COLLECTION_POLICY         NO                                   not_set
# 146                  TN         NO                                   not_set
# 147                  DC         NO                                   not_set
# 148            RELS-EXT         NO                                   not_set
# 149   COLLECTION_POLICY         NO                                   not_set
# 150                  TN         NO                                   not_set
# 151                  DC         NO                                   not_set
#
#                                          checksum_list   Premis_Check  \
# 0    not_set, 94e8f30a05c70096e53be5b1dcb6066769dbb...      Validated
# 1    not_set, 94e8f30a05c70096e53be5b1dcb6066769dbb...      Validated
# 2    not_set, 94e8f30a05c70096e53be5b1dcb6066769dbb...      Validated
# 3    not_set, 94e8f30a05c70096e53be5b1dcb6066769dbb...      Validated
# 4    not_set, 94e8f30a05c70096e53be5b1dcb6066769dbb...      Validated
# 5    not_set, 94e8f30a05c70096e53be5b1dcb6066769dbb...      Validated
# 6    not_set, 94e8f30a05c70096e53be5b1dcb6066769dbb...      Validated
# 7    not_set, 94e8f30a05c70096e53be5b1dcb6066769dbb...      Validated
# 8    not_set, d1c419dba0ca9e133dcdd478ad654b728e1f7...      Validated
# 9    not_set, d1c419dba0ca9e133dcdd478ad654b728e1f7...      Validated
# 10   not_set, d1c419dba0ca9e133dcdd478ad654b728e1f7...      Validated
# 11   not_set, d1c419dba0ca9e133dcdd478ad654b728e1f7...      Validated
# 12   not_set, d1c419dba0ca9e133dcdd478ad654b728e1f7...      Validated
# 13   not_set, d1c419dba0ca9e133dcdd478ad654b728e1f7...      Validated
# 14   not_set, d1c419dba0ca9e133dcdd478ad654b728e1f7...      Validated
# 15   not_set, d1c419dba0ca9e133dcdd478ad654b728e1f7...      Validated
# 16   not_set, 3092d6667f455f236e48a737b1cbd12cbe17a...      Validated
# 17   not_set, 3092d6667f455f236e48a737b1cbd12cbe17a...      Validated
# 18   not_set, 3092d6667f455f236e48a737b1cbd12cbe17a...      Validated
# 19   not_set, 3092d6667f455f236e48a737b1cbd12cbe17a...      Validated
# 20   not_set, 3092d6667f455f236e48a737b1cbd12cbe17a...      Validated
# 21   not_set, 3092d6667f455f236e48a737b1cbd12cbe17a...      Validated
# 22   not_set, 3092d6667f455f236e48a737b1cbd12cbe17a...      Validated
# 23   not_set, 3092d6667f455f236e48a737b1cbd12cbe17a...      Validated
# 24   not_set, 3092d6667f455f236e48a737b1cbd12cbe17a...      Validated
# 25   not_set, 3092d6667f455f236e48a737b1cbd12cbe17a...      Validated
# 26   not_set, 0b34e4584546dc42ef0f0209ca1105ce87cc7...      Validated
# 27   not_set, 0b34e4584546dc42ef0f0209ca1105ce87cc7...      Validated
# 28   not_set, 0b34e4584546dc42ef0f0209ca1105ce87cc7...      Validated
# 29   not_set, 0b34e4584546dc42ef0f0209ca1105ce87cc7...      Validated
# ..                                                 ...            ...
# 122                 not_set, not_set, not_set, not_set  Not Validated
# 123                 not_set, not_set, not_set, not_set  Not Validated
# 124                 not_set, not_set, not_set, not_set  Not Validated
# 125                 not_set, not_set, not_set, not_set  Not Validated
# 126                 not_set, not_set, not_set, not_set  Not Validated
# 127                 not_set, not_set, not_set, not_set  Not Validated
# 128                 not_set, not_set, not_set, not_set  Not Validated
# 129                 not_set, not_set, not_set, not_set  Not Validated
# 130                 not_set, not_set, not_set, not_set  Not Validated
# 131                 not_set, not_set, not_set, not_set  Not Validated
# 132                 not_set, not_set, not_set, not_set  Not Validated
# 133                 not_set, not_set, not_set, not_set  Not Validated
# 134                 not_set, not_set, not_set, not_set  Not Validated
# 135                 not_set, not_set, not_set, not_set  Not Validated
# 136                 not_set, not_set, not_set, not_set  Not Validated
# 137                 not_set, not_set, not_set, not_set  Not Validated
# 138                 not_set, not_set, not_set, not_set  Not Validated
# 139                 not_set, not_set, not_set, not_set  Not Validated
# 140                 not_set, not_set, not_set, not_set  Not Validated
# 141                 not_set, not_set, not_set, not_set  Not Validated
# 142                 not_set, not_set, not_set, not_set  Not Validated
# 143                 not_set, not_set, not_set, not_set  Not Validated
# 144                 not_set, not_set, not_set, not_set  Not Validated
# 145                 not_set, not_set, not_set, not_set  Not Validated
# 146                 not_set, not_set, not_set, not_set  Not Validated
# 147                 not_set, not_set, not_set, not_set  Not Validated
# 148                 not_set, not_set, not_set, not_set  Not Validated
# 149                 not_set, not_set, not_set, not_set  Not Validated
# 150                 not_set, not_set, not_set, not_set  Not Validated
# 151                 not_set, not_set, not_set, not_set  Not Validated
#
#     Last_Modified_By                               obj_format  \
# 0              admin  JPEG File Interchange Format, JPEG EXIF
# 1              admin  JPEG File Interchange Format, JPEG EXIF
# 2              admin  JPEG File Interchange Format, JPEG EXIF
# 3              admin  JPEG File Interchange Format, JPEG EXIF
# 4              admin  JPEG File Interchange Format, JPEG EXIF
# 5              admin  JPEG File Interchange Format, JPEG EXIF
# 6              admin  JPEG File Interchange Format, JPEG EXIF
# 7              admin  JPEG File Interchange Format, JPEG EXIF
# 8              admin  JPEG File Interchange Format, JPEG EXIF
# 9              admin  JPEG File Interchange Format, JPEG EXIF
# 10             admin  JPEG File Interchange Format, JPEG EXIF
# 11             admin  JPEG File Interchange Format, JPEG EXIF
# 12             admin  JPEG File Interchange Format, JPEG EXIF
# 13             admin  JPEG File Interchange Format, JPEG EXIF
# 14             admin  JPEG File Interchange Format, JPEG EXIF
# 15             admin  JPEG File Interchange Format, JPEG EXIF
# 16             admin                                TIFF EXIF
# 17             admin                                TIFF EXIF
# 18             admin                                TIFF EXIF
# 19             admin                                TIFF EXIF
# 20             admin                                TIFF EXIF
# 21             admin                                TIFF EXIF
# 22             admin                                TIFF EXIF
# 23             admin                                TIFF EXIF
# 24             admin                                TIFF EXIF
# 25             admin                                TIFF EXIF
# 26             admin                                TIFF EXIF
# 27             admin                                TIFF EXIF
# 28             admin                                TIFF EXIF
# 29             admin                                TIFF EXIF
# ..               ...                                      ...
# 122              NaN                                      NaN
# 123              NaN                                      NaN
# 124              NaN                                      NaN
# 125              NaN                                      NaN
# 126              NaN                                      NaN
# 127              NaN                                      NaN
# 128              NaN                                      NaN
# 129              NaN                                      NaN
# 130              NaN                                      NaN
# 131              NaN                                      NaN
# 132              NaN                                      NaN
# 133              NaN                                      NaN
# 134              NaN                                      NaN
# 135              NaN                                      NaN
# 136              NaN                                      NaN
# 137              NaN                                      NaN
# 138              NaN                                      NaN
# 139              NaN                                      NaN
# 140              NaN                                      NaN
# 141              NaN                                      NaN
# 142              NaN                                      NaN
# 143              NaN                                      NaN
# 144              NaN                                      NaN
# 145              NaN                                      NaN
# 146              NaN                                      NaN
# 147              NaN                                      NaN
# 148              NaN                                      NaN
# 149              NaN                                      NaN
# 150              NaN                                      NaN
# 151              NaN                                      NaN
#
#                                         mimetypes_list  \
# 0    text/xml, application/rdf+xml, application/xml...
# 1    text/xml, application/rdf+xml, application/xml...
# 2    text/xml, application/rdf+xml, application/xml...
# 3    text/xml, application/rdf+xml, application/xml...
# 4    text/xml, application/rdf+xml, application/xml...
# 5    text/xml, application/rdf+xml, application/xml...
# 6    text/xml, application/rdf+xml, application/xml...
# 7    text/xml, application/rdf+xml, application/xml...
# 8    text/xml, application/rdf+xml, application/xml...
# 9    text/xml, application/rdf+xml, application/xml...
# 10   text/xml, application/rdf+xml, application/xml...
# 11   text/xml, application/rdf+xml, application/xml...
# 12   text/xml, application/rdf+xml, application/xml...
# 13   text/xml, application/rdf+xml, application/xml...
# 14   text/xml, application/rdf+xml, application/xml...
# 15   text/xml, application/rdf+xml, application/xml...
# 16   text/xml, application/rdf+xml, application/pdf...
# 17   text/xml, application/rdf+xml, application/pdf...
# 18   text/xml, application/rdf+xml, application/pdf...
# 19   text/xml, application/rdf+xml, application/pdf...
# 20   text/xml, application/rdf+xml, application/pdf...
# 21   text/xml, application/rdf+xml, application/pdf...
# 22   text/xml, application/rdf+xml, application/pdf...
# 23   text/xml, application/rdf+xml, application/pdf...
# 24   text/xml, application/rdf+xml, application/pdf...
# 25   text/xml, application/rdf+xml, application/pdf...
# 26   text/xml, application/rdf+xml, application/pdf...
# 27   text/xml, application/rdf+xml, application/pdf...
# 28   text/xml, application/rdf+xml, application/pdf...
# 29   text/xml, application/rdf+xml, application/pdf...
# ..                                                 ...
# 122  application/rdf+xml, application/xml, image/pn...
# 123  application/rdf+xml, application/xml, image/pn...
# 124  application/rdf+xml, application/xml, image/pn...
# 125  application/rdf+xml, application/xml, image/pn...
# 126  application/rdf+xml, application/xml, image/pn...
# 127  application/rdf+xml, application/xml, image/pn...
# 128  application/rdf+xml, image/png, text/xml, text...
# 129  application/rdf+xml, image/png, text/xml, text...
# 130  application/rdf+xml, image/png, text/xml, text...
# 131  application/rdf+xml, image/png, text/xml, text...
# 132  application/rdf+xml, application/xml, image/pn...
# 133  application/rdf+xml, application/xml, image/pn...
# 134  application/rdf+xml, application/xml, image/pn...
# 135  application/rdf+xml, application/xml, image/pn...
# 136  application/rdf+xml, application/xml, image/pn...
# 137  application/rdf+xml, application/xml, image/pn...
# 138  application/rdf+xml, application/xml, image/pn...
# 139  application/rdf+xml, application/xml, image/pn...
# 140  application/rdf+xml, application/xml, image/pn...
# 141  application/rdf+xml, application/xml, image/pn...
# 142  application/rdf+xml, application/xml, image/pn...
# 143  application/rdf+xml, application/xml, image/pn...
# 144  application/rdf+xml, application/xml, image/pn...
# 145  application/rdf+xml, application/xml, image/pn...
# 146  application/rdf+xml, application/xml, image/pn...
# 147  application/rdf+xml, application/xml, image/pn...
# 148  application/rdf+xml, application/xml, image/pn...
# 149  application/rdf+xml, application/xml, image/pn...
# 150  application/rdf+xml, application/xml, image/pn...
# 151  application/rdf+xml, application/xml, image/pn...
#
#                       title  \
# 0               second page
# 1               second page
# 2               second page
# 3               second page
# 4               second page
# 5               second page
# 6               second page
# 7               second page
# 8                 back page
# 9                 back page
# 10                back page
# 11                back page
# 12                back page
# 13                back page
# 14                back page
# 15                back page
# 16             sample.pdf-2
# 17             sample.pdf-2
# 18             sample.pdf-2
# 19             sample.pdf-2
# 20             sample.pdf-2
# 21             sample.pdf-2
# 22             sample.pdf-2
# 23             sample.pdf-2
# 24             sample.pdf-2
# 25             sample.pdf-2
# 26             sample.pdf-1
# 27             sample.pdf-1
# 28             sample.pdf-1
# 29             sample.pdf-1
# ..                      ...
# 122    Newspaper Collection
# 123    Newspaper Collection
# 124  Large Image Collection
# 125  Large Image Collection
# 126  Large Image Collection
# 127  Large Image Collection
# 128       Entity Collection
# 129       Entity Collection
# 130       Entity Collection
# 131       Entity Collection
# 132   Disk Image Collection
# 133   Disk Image Collection
# 134   Disk Image Collection
# 135   Disk Image Collection
# 136     Compound Collection
# 137     Compound Collection
# 138     Compound Collection
# 139     Compound Collection
# 140         Book Collection
# 141         Book Collection
# 142         Book Collection
# 143         Book Collection
# 144        Audio Collection
# 145        Audio Collection
# 146        Audio Collection
# 147        Audio Collection
# 148    Top-level Collection
# 149    Top-level Collection
# 150    Top-level Collection
# 151    Top-level Collection
#
#                                              size_list  \
# 0    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 1    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 2    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 3    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 4    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 5    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 6    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 7    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 8    not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 9    not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 10   not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 11   not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 12   not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 13   not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 14   not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 15   not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 16   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 17   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 18   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 19   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 20   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 21   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 22   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 23   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 24   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 25   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 26   not_set, 822, 6185, 298854, 374, 189257, 14929...
# 27   not_set, 822, 6185, 298854, 374, 189257, 14929...
# 28   not_set, 822, 6185, 298854, 374, 189257, 14929...
# 29   not_set, 822, 6185, 298854, 374, 189257, 14929...
# ..                                                 ...
# 122                                579, 690, 5137, 402
# 123                                579, 690, 5137, 402
# 124                                584, 535, 5137, 409
# 125                                584, 535, 5137, 409
# 126                                584, 535, 5137, 409
# 127                                584, 535, 5137, 409
# 128                                576, 5137, 936, 396
# 129                                576, 5137, 936, 396
# 130                                576, 5137, 936, 396
# 131                                576, 5137, 936, 396
# 132                                583, 528, 5137, 407
# 133                                583, 528, 5137, 407
# 134                                583, 528, 5137, 407
# 135                                583, 528, 5137, 407
# 136                                578, 726, 5137, 400
# 137                                578, 726, 5137, 400
# 138                                578, 726, 5137, 400
# 139                                578, 726, 5137, 400
# 140                               573, 1165, 5137, 391
# 141                               573, 1165, 5137, 391
# 142                               573, 1165, 5137, 391
# 143                               573, 1165, 5137, 391
# 144                                575, 510, 5137, 394
# 145                                575, 510, 5137, 394
# 146                                575, 510, 5137, 394
# 147                                575, 510, 5137, 394
# 148                               457, 1209, 5137, 386
# 149                               457, 1209, 5137, 386
# 150                               457, 1209, 5137, 386
# 151                               457, 1209, 5137, 386
#
#               fgs_lastModifiedDate_dt  checksum_count  namespace
# 0     Tuesday, March 26, 2019 - 01:05               8  islandora
# 1     Tuesday, March 26, 2019 - 01:05               8  islandora
# 2     Tuesday, March 26, 2019 - 01:05               8  islandora
# 3     Tuesday, March 26, 2019 - 01:05               8  islandora
# 4     Tuesday, March 26, 2019 - 01:05               8  islandora
# 5     Tuesday, March 26, 2019 - 01:05               8  islandora
# 6     Tuesday, March 26, 2019 - 01:05               8  islandora
# 7     Tuesday, March 26, 2019 - 01:05               8  islandora
# 8     Tuesday, March 26, 2019 - 01:05               8  islandora
# 9     Tuesday, March 26, 2019 - 01:05               8  islandora
# 10    Tuesday, March 26, 2019 - 01:05               8  islandora
# 11    Tuesday, March 26, 2019 - 01:05               8  islandora
# 12    Tuesday, March 26, 2019 - 01:05               8  islandora
# 13    Tuesday, March 26, 2019 - 01:05               8  islandora
# 14    Tuesday, March 26, 2019 - 01:05               8  islandora
# 15    Tuesday, March 26, 2019 - 01:05               8  islandora
# 16    Tuesday, March 26, 2019 - 01:05              10    example
# 17    Tuesday, March 26, 2019 - 01:05              10    example
# 18    Tuesday, March 26, 2019 - 01:05              10    example
# 19    Tuesday, March 26, 2019 - 01:05              10    example
# 20    Tuesday, March 26, 2019 - 01:05              10    example
# 21    Tuesday, March 26, 2019 - 01:05              10    example
# 22    Tuesday, March 26, 2019 - 01:05              10    example
# 23    Tuesday, March 26, 2019 - 01:05              10    example
# 24    Tuesday, March 26, 2019 - 01:05              10    example
# 25    Tuesday, March 26, 2019 - 01:05              10    example
# 26    Tuesday, March 26, 2019 - 01:05              10    example
# 27    Tuesday, March 26, 2019 - 01:05              10    example
# 28    Tuesday, March 26, 2019 - 01:05              10    example
# 29    Tuesday, March 26, 2019 - 01:05              10    example
# ..                                ...             ...        ...
# 122  Thursday, March 21, 2019 - 16:22               4  islandora
# 123  Thursday, March 21, 2019 - 16:22               4  islandora
# 124  Thursday, March 21, 2019 - 16:22               4  islandora
# 125  Thursday, March 21, 2019 - 16:22               4  islandora
# 126  Thursday, March 21, 2019 - 16:22               4  islandora
# 127  Thursday, March 21, 2019 - 16:22               4  islandora
# 128  Thursday, March 21, 2019 - 16:22               4  islandora
# 129  Thursday, March 21, 2019 - 16:22               4  islandora
# 130  Thursday, March 21, 2019 - 16:22               4  islandora
# 131  Thursday, March 21, 2019 - 16:22               4  islandora
# 132  Thursday, March 21, 2019 - 16:22               4  islandora
# 133  Thursday, March 21, 2019 - 16:22               4  islandora
# 134  Thursday, March 21, 2019 - 16:22               4  islandora
# 135  Thursday, March 21, 2019 - 16:22               4  islandora
# 136  Thursday, March 21, 2019 - 16:22               4  islandora
# 137  Thursday, March 21, 2019 - 16:22               4  islandora
# 138  Thursday, March 21, 2019 - 16:22               4  islandora
# 139  Thursday, March 21, 2019 - 16:22               4  islandora
# 140  Thursday, March 21, 2019 - 16:22               4  islandora
# 141  Thursday, March 21, 2019 - 16:22               4  islandora
# 142  Thursday, March 21, 2019 - 16:22               4  islandora
# 143  Thursday, March 21, 2019 - 16:22               4  islandora
# 144  Thursday, March 21, 2019 - 16:22               4  islandora
# 145  Thursday, March 21, 2019 - 16:22               4  islandora
# 146  Thursday, March 21, 2019 - 16:22               4  islandora
# 147  Thursday, March 21, 2019 - 16:22               4  islandora
# 148  Thursday, March 21, 2019 - 16:22               4  islandora
# 149  Thursday, March 21, 2019 - 16:22               4  islandora
# 150  Thursday, March 21, 2019 - 16:22               4  islandora
# 151  Thursday, March 21, 2019 - 16:22               4  islandora
#
# [152 rows x 17 columns]

# %%
df_checksum = \
(df.set_index(df.columns.drop('checksum_list',1).tolist())
   .checksum_list.str.split(',', expand=True)
   .stack()
   .reset_index()
   .rename(columns={0:'checksum_list'})
   .loc[:, df.columns]
)

# %%
del df_ds["checksum_list"]
del df_ds["checksum_count"]
df_ds["checksum"] = df_checksum.checksum_list

# %%
df_mimetypes = \
(df.set_index(df.columns.drop('mimetypes_list',1).tolist())
   .mimetypes_list.str.split(',', expand=True)
   .stack()
   .reset_index()
   .rename(columns={0:'mimetypes_list'})
   .loc[:, df.columns]
)

# %%
df_mimetypes
# Out:
#                                      PID        isMemberOfCollection  \
# 0                           islandora:11     info:fedora/example:nat
# 1                           islandora:11     info:fedora/example:nat
# 2                           islandora:11     info:fedora/example:nat
# 3                           islandora:11     info:fedora/example:nat
# 4                           islandora:11     info:fedora/example:nat
# 5                           islandora:11     info:fedora/example:nat
# 6                           islandora:11     info:fedora/example:nat
# 7                           islandora:11     info:fedora/example:nat
# 8                           islandora:10     info:fedora/example:nat
# 9                           islandora:10     info:fedora/example:nat
# 10                          islandora:10     info:fedora/example:nat
# 11                          islandora:10     info:fedora/example:nat
# 12                          islandora:10     info:fedora/example:nat
# 13                          islandora:10     info:fedora/example:nat
# 14                          islandora:10     info:fedora/example:nat
# 15                          islandora:10     info:fedora/example:nat
# 16                             example:3                         NaN
# 17                             example:3                         NaN
# 18                             example:3                         NaN
# 19                             example:3                         NaN
# 20                             example:3                         NaN
# 21                             example:3                         NaN
# 22                             example:3                         NaN
# 23                             example:3                         NaN
# 24                             example:3                         NaN
# 25                             example:3                         NaN
# 26                             example:2                         NaN
# 27                             example:2                         NaN
# 28                             example:2                         NaN
# 29                             example:2                         NaN
# ..                                   ...                         ...
# 122       islandora:newspaper_collection  info:fedora/islandora:root
# 123       islandora:newspaper_collection  info:fedora/islandora:root
# 124  islandora:sp_large_image_collection  info:fedora/islandora:root
# 125  islandora:sp_large_image_collection  info:fedora/islandora:root
# 126  islandora:sp_large_image_collection  info:fedora/islandora:root
# 127  islandora:sp_large_image_collection  info:fedora/islandora:root
# 128          islandora:entity_collection  info:fedora/islandora:root
# 129          islandora:entity_collection  info:fedora/islandora:root
# 130          islandora:entity_collection  info:fedora/islandora:root
# 131          islandora:entity_collection  info:fedora/islandora:root
# 132   islandora:sp_disk_image_collection  info:fedora/islandora:root
# 133   islandora:sp_disk_image_collection  info:fedora/islandora:root
# 134   islandora:sp_disk_image_collection  info:fedora/islandora:root
# 135   islandora:sp_disk_image_collection  info:fedora/islandora:root
# 136        islandora:compound_collection  info:fedora/islandora:root
# 137        islandora:compound_collection  info:fedora/islandora:root
# 138        islandora:compound_collection  info:fedora/islandora:root
# 139        islandora:compound_collection  info:fedora/islandora:root
# 140             islandora:bookCollection  info:fedora/islandora:root
# 141             islandora:bookCollection  info:fedora/islandora:root
# 142             islandora:bookCollection  info:fedora/islandora:root
# 143             islandora:bookCollection  info:fedora/islandora:root
# 144           islandora:audio_collection  info:fedora/islandora:root
# 145           islandora:audio_collection  info:fedora/islandora:root
# 146           islandora:audio_collection  info:fedora/islandora:root
# 147           islandora:audio_collection  info:fedora/islandora:root
# 148                       islandora:root                         NaN
# 149                       islandora:root                         NaN
# 150                       islandora:root                         NaN
# 151                       islandora:root                         NaN
#
#                   isPageOf                                  cmodel  \
# 0                      NaN    info:fedora/islandora:sp_basic_image
# 1                      NaN    info:fedora/islandora:sp_basic_image
# 2                      NaN    info:fedora/islandora:sp_basic_image
# 3                      NaN    info:fedora/islandora:sp_basic_image
# 4                      NaN    info:fedora/islandora:sp_basic_image
# 5                      NaN    info:fedora/islandora:sp_basic_image
# 6                      NaN    info:fedora/islandora:sp_basic_image
# 7                      NaN    info:fedora/islandora:sp_basic_image
# 8                      NaN    info:fedora/islandora:sp_basic_image
# 9                      NaN    info:fedora/islandora:sp_basic_image
# 10                     NaN    info:fedora/islandora:sp_basic_image
# 11                     NaN    info:fedora/islandora:sp_basic_image
# 12                     NaN    info:fedora/islandora:sp_basic_image
# 13                     NaN    info:fedora/islandora:sp_basic_image
# 14                     NaN    info:fedora/islandora:sp_basic_image
# 15                     NaN    info:fedora/islandora:sp_basic_image
# 16   info:fedora/example:1        info:fedora/islandora:pageCModel
# 17   info:fedora/example:1        info:fedora/islandora:pageCModel
# 18   info:fedora/example:1        info:fedora/islandora:pageCModel
# 19   info:fedora/example:1        info:fedora/islandora:pageCModel
# 20   info:fedora/example:1        info:fedora/islandora:pageCModel
# 21   info:fedora/example:1        info:fedora/islandora:pageCModel
# 22   info:fedora/example:1        info:fedora/islandora:pageCModel
# 23   info:fedora/example:1        info:fedora/islandora:pageCModel
# 24   info:fedora/example:1        info:fedora/islandora:pageCModel
# 25   info:fedora/example:1        info:fedora/islandora:pageCModel
# 26   info:fedora/example:1        info:fedora/islandora:pageCModel
# 27   info:fedora/example:1        info:fedora/islandora:pageCModel
# 28   info:fedora/example:1        info:fedora/islandora:pageCModel
# 29   info:fedora/example:1        info:fedora/islandora:pageCModel
# ..                     ...                                     ...
# 122                    NaN  info:fedora/islandora:collectionCModel
# 123                    NaN  info:fedora/islandora:collectionCModel
# 124                    NaN  info:fedora/islandora:collectionCModel
# 125                    NaN  info:fedora/islandora:collectionCModel
# 126                    NaN  info:fedora/islandora:collectionCModel
# 127                    NaN  info:fedora/islandora:collectionCModel
# 128                    NaN  info:fedora/islandora:collectionCModel
# 129                    NaN  info:fedora/islandora:collectionCModel
# 130                    NaN  info:fedora/islandora:collectionCModel
# 131                    NaN  info:fedora/islandora:collectionCModel
# 132                    NaN  info:fedora/islandora:collectionCModel
# 133                    NaN  info:fedora/islandora:collectionCModel
# 134                    NaN  info:fedora/islandora:collectionCModel
# 135                    NaN  info:fedora/islandora:collectionCModel
# 136                    NaN  info:fedora/islandora:collectionCModel
# 137                    NaN  info:fedora/islandora:collectionCModel
# 138                    NaN  info:fedora/islandora:collectionCModel
# 139                    NaN  info:fedora/islandora:collectionCModel
# 140                    NaN  info:fedora/islandora:collectionCModel
# 141                    NaN  info:fedora/islandora:collectionCModel
# 142                    NaN  info:fedora/islandora:collectionCModel
# 143                    NaN  info:fedora/islandora:collectionCModel
# 144                    NaN  info:fedora/islandora:collectionCModel
# 145                    NaN  info:fedora/islandora:collectionCModel
# 146                    NaN  info:fedora/islandora:collectionCModel
# 147                    NaN  info:fedora/islandora:collectionCModel
# 148                    NaN  info:fedora/islandora:collectionCModel
# 149                    NaN  info:fedora/islandora:collectionCModel
# 150                    NaN  info:fedora/islandora:collectionCModel
# 151                    NaN  info:fedora/islandora:collectionCModel
#
#                                        datastream_list  datastreams_count  \
# 0    AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 1    AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 2    AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 3    AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 4    AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 5    AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 6    AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 7    AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 8    AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 9    AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 10   AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 11   AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 12   AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 13   AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 14   AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 15   AUDIT, RELS-EXT, MODS, DC, OBJ, TECHMD, TN, ME...                  8
# 16   AUDIT, RELS-EXT, PDF, OBJ, DC, TN, JP2, TECHMD...                 10
# 17   AUDIT, RELS-EXT, PDF, OBJ, DC, TN, JP2, TECHMD...                 10
# 18   AUDIT, RELS-EXT, PDF, OBJ, DC, TN, JP2, TECHMD...                 10
# 19   AUDIT, RELS-EXT, PDF, OBJ, DC, TN, JP2, TECHMD...                 10
# 20   AUDIT, RELS-EXT, PDF, OBJ, DC, TN, JP2, TECHMD...                 10
# 21   AUDIT, RELS-EXT, PDF, OBJ, DC, TN, JP2, TECHMD...                 10
# 22   AUDIT, RELS-EXT, PDF, OBJ, DC, TN, JP2, TECHMD...                 10
# 23   AUDIT, RELS-EXT, PDF, OBJ, DC, TN, JP2, TECHMD...                 10
# 24   AUDIT, RELS-EXT, PDF, OBJ, DC, TN, JP2, TECHMD...                 10
# 25   AUDIT, RELS-EXT, PDF, OBJ, DC, TN, JP2, TECHMD...                 10
# 26   AUDIT, RELS-EXT, PDF, OBJ, DC, TN, JP2, TECHMD...                 10
# 27   AUDIT, RELS-EXT, PDF, OBJ, DC, TN, JP2, TECHMD...                 10
# 28   AUDIT, RELS-EXT, PDF, OBJ, DC, TN, JP2, TECHMD...                 10
# 29   AUDIT, RELS-EXT, PDF, OBJ, DC, TN, JP2, TECHMD...                 10
# ..                                                 ...                ...
# 122                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 123                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 124                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 125                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 126                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 127                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 128                RELS-EXT, TN, COLLECTION_POLICY, DC                  4
# 129                RELS-EXT, TN, COLLECTION_POLICY, DC                  4
# 130                RELS-EXT, TN, COLLECTION_POLICY, DC                  4
# 131                RELS-EXT, TN, COLLECTION_POLICY, DC                  4
# 132                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 133                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 134                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 135                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 136                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 137                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 138                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 139                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 140                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 141                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 142                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 143                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 144                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 145                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 146                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 147                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 148                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 149                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 150                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
# 151                RELS-EXT, COLLECTION_POLICY, TN, DC                  4
#
#     OBJ_Exists                              obj_checksum  \
# 0          OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 1          OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 2          OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 3          OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 4          OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 5          OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 6          OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 7          OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 8          OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 9          OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 10         OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 11         OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 12         OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 13         OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 14         OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 15         OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 16         OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 17         OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 18         OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 19         OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 20         OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 21         OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 22         OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 23         OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 24         OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 25         OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 26         OBJ  cd3b241ed4869776bb90387b51766e04b7a62151
# 27         OBJ  cd3b241ed4869776bb90387b51766e04b7a62151
# 28         OBJ  cd3b241ed4869776bb90387b51766e04b7a62151
# 29         OBJ  cd3b241ed4869776bb90387b51766e04b7a62151
# ..         ...                                       ...
# 122         NO                                   not_set
# 123         NO                                   not_set
# 124         NO                                   not_set
# 125         NO                                   not_set
# 126         NO                                   not_set
# 127         NO                                   not_set
# 128         NO                                   not_set
# 129         NO                                   not_set
# 130         NO                                   not_set
# 131         NO                                   not_set
# 132         NO                                   not_set
# 133         NO                                   not_set
# 134         NO                                   not_set
# 135         NO                                   not_set
# 136         NO                                   not_set
# 137         NO                                   not_set
# 138         NO                                   not_set
# 139         NO                                   not_set
# 140         NO                                   not_set
# 141         NO                                   not_set
# 142         NO                                   not_set
# 143         NO                                   not_set
# 144         NO                                   not_set
# 145         NO                                   not_set
# 146         NO                                   not_set
# 147         NO                                   not_set
# 148         NO                                   not_set
# 149         NO                                   not_set
# 150         NO                                   not_set
# 151         NO                                   not_set
#
#                                          checksum_list   Premis_Check  \
# 0    not_set, 94e8f30a05c70096e53be5b1dcb6066769dbb...      Validated
# 1    not_set, 94e8f30a05c70096e53be5b1dcb6066769dbb...      Validated
# 2    not_set, 94e8f30a05c70096e53be5b1dcb6066769dbb...      Validated
# 3    not_set, 94e8f30a05c70096e53be5b1dcb6066769dbb...      Validated
# 4    not_set, 94e8f30a05c70096e53be5b1dcb6066769dbb...      Validated
# 5    not_set, 94e8f30a05c70096e53be5b1dcb6066769dbb...      Validated
# 6    not_set, 94e8f30a05c70096e53be5b1dcb6066769dbb...      Validated
# 7    not_set, 94e8f30a05c70096e53be5b1dcb6066769dbb...      Validated
# 8    not_set, d1c419dba0ca9e133dcdd478ad654b728e1f7...      Validated
# 9    not_set, d1c419dba0ca9e133dcdd478ad654b728e1f7...      Validated
# 10   not_set, d1c419dba0ca9e133dcdd478ad654b728e1f7...      Validated
# 11   not_set, d1c419dba0ca9e133dcdd478ad654b728e1f7...      Validated
# 12   not_set, d1c419dba0ca9e133dcdd478ad654b728e1f7...      Validated
# 13   not_set, d1c419dba0ca9e133dcdd478ad654b728e1f7...      Validated
# 14   not_set, d1c419dba0ca9e133dcdd478ad654b728e1f7...      Validated
# 15   not_set, d1c419dba0ca9e133dcdd478ad654b728e1f7...      Validated
# 16   not_set, 3092d6667f455f236e48a737b1cbd12cbe17a...      Validated
# 17   not_set, 3092d6667f455f236e48a737b1cbd12cbe17a...      Validated
# 18   not_set, 3092d6667f455f236e48a737b1cbd12cbe17a...      Validated
# 19   not_set, 3092d6667f455f236e48a737b1cbd12cbe17a...      Validated
# 20   not_set, 3092d6667f455f236e48a737b1cbd12cbe17a...      Validated
# 21   not_set, 3092d6667f455f236e48a737b1cbd12cbe17a...      Validated
# 22   not_set, 3092d6667f455f236e48a737b1cbd12cbe17a...      Validated
# 23   not_set, 3092d6667f455f236e48a737b1cbd12cbe17a...      Validated
# 24   not_set, 3092d6667f455f236e48a737b1cbd12cbe17a...      Validated
# 25   not_set, 3092d6667f455f236e48a737b1cbd12cbe17a...      Validated
# 26   not_set, 0b34e4584546dc42ef0f0209ca1105ce87cc7...      Validated
# 27   not_set, 0b34e4584546dc42ef0f0209ca1105ce87cc7...      Validated
# 28   not_set, 0b34e4584546dc42ef0f0209ca1105ce87cc7...      Validated
# 29   not_set, 0b34e4584546dc42ef0f0209ca1105ce87cc7...      Validated
# ..                                                 ...            ...
# 122                 not_set, not_set, not_set, not_set  Not Validated
# 123                 not_set, not_set, not_set, not_set  Not Validated
# 124                 not_set, not_set, not_set, not_set  Not Validated
# 125                 not_set, not_set, not_set, not_set  Not Validated
# 126                 not_set, not_set, not_set, not_set  Not Validated
# 127                 not_set, not_set, not_set, not_set  Not Validated
# 128                 not_set, not_set, not_set, not_set  Not Validated
# 129                 not_set, not_set, not_set, not_set  Not Validated
# 130                 not_set, not_set, not_set, not_set  Not Validated
# 131                 not_set, not_set, not_set, not_set  Not Validated
# 132                 not_set, not_set, not_set, not_set  Not Validated
# 133                 not_set, not_set, not_set, not_set  Not Validated
# 134                 not_set, not_set, not_set, not_set  Not Validated
# 135                 not_set, not_set, not_set, not_set  Not Validated
# 136                 not_set, not_set, not_set, not_set  Not Validated
# 137                 not_set, not_set, not_set, not_set  Not Validated
# 138                 not_set, not_set, not_set, not_set  Not Validated
# 139                 not_set, not_set, not_set, not_set  Not Validated
# 140                 not_set, not_set, not_set, not_set  Not Validated
# 141                 not_set, not_set, not_set, not_set  Not Validated
# 142                 not_set, not_set, not_set, not_set  Not Validated
# 143                 not_set, not_set, not_set, not_set  Not Validated
# 144                 not_set, not_set, not_set, not_set  Not Validated
# 145                 not_set, not_set, not_set, not_set  Not Validated
# 146                 not_set, not_set, not_set, not_set  Not Validated
# 147                 not_set, not_set, not_set, not_set  Not Validated
# 148                 not_set, not_set, not_set, not_set  Not Validated
# 149                 not_set, not_set, not_set, not_set  Not Validated
# 150                 not_set, not_set, not_set, not_set  Not Validated
# 151                 not_set, not_set, not_set, not_set  Not Validated
#
#     Last_Modified_By                               obj_format  \
# 0              admin  JPEG File Interchange Format, JPEG EXIF
# 1              admin  JPEG File Interchange Format, JPEG EXIF
# 2              admin  JPEG File Interchange Format, JPEG EXIF
# 3              admin  JPEG File Interchange Format, JPEG EXIF
# 4              admin  JPEG File Interchange Format, JPEG EXIF
# 5              admin  JPEG File Interchange Format, JPEG EXIF
# 6              admin  JPEG File Interchange Format, JPEG EXIF
# 7              admin  JPEG File Interchange Format, JPEG EXIF
# 8              admin  JPEG File Interchange Format, JPEG EXIF
# 9              admin  JPEG File Interchange Format, JPEG EXIF
# 10             admin  JPEG File Interchange Format, JPEG EXIF
# 11             admin  JPEG File Interchange Format, JPEG EXIF
# 12             admin  JPEG File Interchange Format, JPEG EXIF
# 13             admin  JPEG File Interchange Format, JPEG EXIF
# 14             admin  JPEG File Interchange Format, JPEG EXIF
# 15             admin  JPEG File Interchange Format, JPEG EXIF
# 16             admin                                TIFF EXIF
# 17             admin                                TIFF EXIF
# 18             admin                                TIFF EXIF
# 19             admin                                TIFF EXIF
# 20             admin                                TIFF EXIF
# 21             admin                                TIFF EXIF
# 22             admin                                TIFF EXIF
# 23             admin                                TIFF EXIF
# 24             admin                                TIFF EXIF
# 25             admin                                TIFF EXIF
# 26             admin                                TIFF EXIF
# 27             admin                                TIFF EXIF
# 28             admin                                TIFF EXIF
# 29             admin                                TIFF EXIF
# ..               ...                                      ...
# 122              NaN                                      NaN
# 123              NaN                                      NaN
# 124              NaN                                      NaN
# 125              NaN                                      NaN
# 126              NaN                                      NaN
# 127              NaN                                      NaN
# 128              NaN                                      NaN
# 129              NaN                                      NaN
# 130              NaN                                      NaN
# 131              NaN                                      NaN
# 132              NaN                                      NaN
# 133              NaN                                      NaN
# 134              NaN                                      NaN
# 135              NaN                                      NaN
# 136              NaN                                      NaN
# 137              NaN                                      NaN
# 138              NaN                                      NaN
# 139              NaN                                      NaN
# 140              NaN                                      NaN
# 141              NaN                                      NaN
# 142              NaN                                      NaN
# 143              NaN                                      NaN
# 144              NaN                                      NaN
# 145              NaN                                      NaN
# 146              NaN                                      NaN
# 147              NaN                                      NaN
# 148              NaN                                      NaN
# 149              NaN                                      NaN
# 150              NaN                                      NaN
# 151              NaN                                      NaN
#
#            mimetypes_list                   title  \
# 0                text/xml             second page
# 1     application/rdf+xml             second page
# 2         application/xml             second page
# 3                text/xml             second page
# 4              image/jpeg             second page
# 5         application/xml             second page
# 6              image/jpeg             second page
# 7              image/jpeg             second page
# 8                text/xml               back page
# 9     application/rdf+xml               back page
# 10        application/xml               back page
# 11               text/xml               back page
# 12             image/jpeg               back page
# 13        application/xml               back page
# 14             image/jpeg               back page
# 15             image/jpeg               back page
# 16               text/xml            sample.pdf-2
# 17    application/rdf+xml            sample.pdf-2
# 18        application/pdf            sample.pdf-2
# 19             image/tiff            sample.pdf-2
# 20               text/xml            sample.pdf-2
# 21             image/jpeg            sample.pdf-2
# 22              image/jp2            sample.pdf-2
# 23        application/xml            sample.pdf-2
# 24             image/jpeg            sample.pdf-2
# 25    application/rdf+xml            sample.pdf-2
# 26               text/xml            sample.pdf-1
# 27    application/rdf+xml            sample.pdf-1
# 28        application/pdf            sample.pdf-1
# 29             image/tiff            sample.pdf-1
# ..                    ...                     ...
# 122             image/png    Newspaper Collection
# 123              text/xml    Newspaper Collection
# 124   application/rdf+xml  Large Image Collection
# 125       application/xml  Large Image Collection
# 126             image/png  Large Image Collection
# 127              text/xml  Large Image Collection
# 128   application/rdf+xml       Entity Collection
# 129             image/png       Entity Collection
# 130              text/xml       Entity Collection
# 131              text/xml       Entity Collection
# 132   application/rdf+xml   Disk Image Collection
# 133       application/xml   Disk Image Collection
# 134             image/png   Disk Image Collection
# 135              text/xml   Disk Image Collection
# 136   application/rdf+xml     Compound Collection
# 137       application/xml     Compound Collection
# 138             image/png     Compound Collection
# 139              text/xml     Compound Collection
# 140   application/rdf+xml         Book Collection
# 141       application/xml         Book Collection
# 142             image/png         Book Collection
# 143              text/xml         Book Collection
# 144   application/rdf+xml        Audio Collection
# 145       application/xml        Audio Collection
# 146             image/png        Audio Collection
# 147              text/xml        Audio Collection
# 148   application/rdf+xml    Top-level Collection
# 149       application/xml    Top-level Collection
# 150             image/png    Top-level Collection
# 151              text/xml    Top-level Collection
#
#                                              size_list  \
# 0    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 1    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 2    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 3    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 4    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 5    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 6    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 7    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 8    not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 9    not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 10   not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 11   not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 12   not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 13   not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 14   not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 15   not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 16   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 17   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 18   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 19   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 20   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 21   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 22   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 23   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 24   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 25   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 26   not_set, 822, 6185, 298854, 374, 189257, 14929...
# 27   not_set, 822, 6185, 298854, 374, 189257, 14929...
# 28   not_set, 822, 6185, 298854, 374, 189257, 14929...
# 29   not_set, 822, 6185, 298854, 374, 189257, 14929...
# ..                                                 ...
# 122                                579, 690, 5137, 402
# 123                                579, 690, 5137, 402
# 124                                584, 535, 5137, 409
# 125                                584, 535, 5137, 409
# 126                                584, 535, 5137, 409
# 127                                584, 535, 5137, 409
# 128                                576, 5137, 936, 396
# 129                                576, 5137, 936, 396
# 130                                576, 5137, 936, 396
# 131                                576, 5137, 936, 396
# 132                                583, 528, 5137, 407
# 133                                583, 528, 5137, 407
# 134                                583, 528, 5137, 407
# 135                                583, 528, 5137, 407
# 136                                578, 726, 5137, 400
# 137                                578, 726, 5137, 400
# 138                                578, 726, 5137, 400
# 139                                578, 726, 5137, 400
# 140                               573, 1165, 5137, 391
# 141                               573, 1165, 5137, 391
# 142                               573, 1165, 5137, 391
# 143                               573, 1165, 5137, 391
# 144                                575, 510, 5137, 394
# 145                                575, 510, 5137, 394
# 146                                575, 510, 5137, 394
# 147                                575, 510, 5137, 394
# 148                               457, 1209, 5137, 386
# 149                               457, 1209, 5137, 386
# 150                               457, 1209, 5137, 386
# 151                               457, 1209, 5137, 386
#
#               fgs_lastModifiedDate_dt  checksum_count  namespace
# 0     Tuesday, March 26, 2019 - 01:05               8  islandora
# 1     Tuesday, March 26, 2019 - 01:05               8  islandora
# 2     Tuesday, March 26, 2019 - 01:05               8  islandora
# 3     Tuesday, March 26, 2019 - 01:05               8  islandora
# 4     Tuesday, March 26, 2019 - 01:05               8  islandora
# 5     Tuesday, March 26, 2019 - 01:05               8  islandora
# 6     Tuesday, March 26, 2019 - 01:05               8  islandora
# 7     Tuesday, March 26, 2019 - 01:05               8  islandora
# 8     Tuesday, March 26, 2019 - 01:05               8  islandora
# 9     Tuesday, March 26, 2019 - 01:05               8  islandora
# 10    Tuesday, March 26, 2019 - 01:05               8  islandora
# 11    Tuesday, March 26, 2019 - 01:05               8  islandora
# 12    Tuesday, March 26, 2019 - 01:05               8  islandora
# 13    Tuesday, March 26, 2019 - 01:05               8  islandora
# 14    Tuesday, March 26, 2019 - 01:05               8  islandora
# 15    Tuesday, March 26, 2019 - 01:05               8  islandora
# 16    Tuesday, March 26, 2019 - 01:05              10    example
# 17    Tuesday, March 26, 2019 - 01:05              10    example
# 18    Tuesday, March 26, 2019 - 01:05              10    example
# 19    Tuesday, March 26, 2019 - 01:05              10    example
# 20    Tuesday, March 26, 2019 - 01:05              10    example
# 21    Tuesday, March 26, 2019 - 01:05              10    example
# 22    Tuesday, March 26, 2019 - 01:05              10    example
# 23    Tuesday, March 26, 2019 - 01:05              10    example
# 24    Tuesday, March 26, 2019 - 01:05              10    example
# 25    Tuesday, March 26, 2019 - 01:05              10    example
# 26    Tuesday, March 26, 2019 - 01:05              10    example
# 27    Tuesday, March 26, 2019 - 01:05              10    example
# 28    Tuesday, March 26, 2019 - 01:05              10    example
# 29    Tuesday, March 26, 2019 - 01:05              10    example
# ..                                ...             ...        ...
# 122  Thursday, March 21, 2019 - 16:22               4  islandora
# 123  Thursday, March 21, 2019 - 16:22               4  islandora
# 124  Thursday, March 21, 2019 - 16:22               4  islandora
# 125  Thursday, March 21, 2019 - 16:22               4  islandora
# 126  Thursday, March 21, 2019 - 16:22               4  islandora
# 127  Thursday, March 21, 2019 - 16:22               4  islandora
# 128  Thursday, March 21, 2019 - 16:22               4  islandora
# 129  Thursday, March 21, 2019 - 16:22               4  islandora
# 130  Thursday, March 21, 2019 - 16:22               4  islandora
# 131  Thursday, March 21, 2019 - 16:22               4  islandora
# 132  Thursday, March 21, 2019 - 16:22               4  islandora
# 133  Thursday, March 21, 2019 - 16:22               4  islandora
# 134  Thursday, March 21, 2019 - 16:22               4  islandora
# 135  Thursday, March 21, 2019 - 16:22               4  islandora
# 136  Thursday, March 21, 2019 - 16:22               4  islandora
# 137  Thursday, March 21, 2019 - 16:22               4  islandora
# 138  Thursday, March 21, 2019 - 16:22               4  islandora
# 139  Thursday, March 21, 2019 - 16:22               4  islandora
# 140  Thursday, March 21, 2019 - 16:22               4  islandora
# 141  Thursday, March 21, 2019 - 16:22               4  islandora
# 142  Thursday, March 21, 2019 - 16:22               4  islandora
# 143  Thursday, March 21, 2019 - 16:22               4  islandora
# 144  Thursday, March 21, 2019 - 16:22               4  islandora
# 145  Thursday, March 21, 2019 - 16:22               4  islandora
# 146  Thursday, March 21, 2019 - 16:22               4  islandora
# 147  Thursday, March 21, 2019 - 16:22               4  islandora
# 148  Thursday, March 21, 2019 - 16:22               4  islandora
# 149  Thursday, March 21, 2019 - 16:22               4  islandora
# 150  Thursday, March 21, 2019 - 16:22               4  islandora
# 151  Thursday, March 21, 2019 - 16:22               4  islandora
#
# [152 rows x 18 columns]

# %%
del df_ds["mimetypes_list"]
df_ds["mimetype"] = df_mimetypes.mimetypes_list

# %%
df_ds
# Out:
#                                      PID        isMemberOfCollection  \
# 0                           islandora:11     info:fedora/example:nat
# 1                           islandora:11     info:fedora/example:nat
# 2                           islandora:11     info:fedora/example:nat
# 3                           islandora:11     info:fedora/example:nat
# 4                           islandora:11     info:fedora/example:nat
# 5                           islandora:11     info:fedora/example:nat
# 6                           islandora:11     info:fedora/example:nat
# 7                           islandora:11     info:fedora/example:nat
# 8                           islandora:10     info:fedora/example:nat
# 9                           islandora:10     info:fedora/example:nat
# 10                          islandora:10     info:fedora/example:nat
# 11                          islandora:10     info:fedora/example:nat
# 12                          islandora:10     info:fedora/example:nat
# 13                          islandora:10     info:fedora/example:nat
# 14                          islandora:10     info:fedora/example:nat
# 15                          islandora:10     info:fedora/example:nat
# 16                             example:3                         NaN
# 17                             example:3                         NaN
# 18                             example:3                         NaN
# 19                             example:3                         NaN
# 20                             example:3                         NaN
# 21                             example:3                         NaN
# 22                             example:3                         NaN
# 23                             example:3                         NaN
# 24                             example:3                         NaN
# 25                             example:3                         NaN
# 26                             example:2                         NaN
# 27                             example:2                         NaN
# 28                             example:2                         NaN
# 29                             example:2                         NaN
# ..                                   ...                         ...
# 122       islandora:newspaper_collection  info:fedora/islandora:root
# 123       islandora:newspaper_collection  info:fedora/islandora:root
# 124  islandora:sp_large_image_collection  info:fedora/islandora:root
# 125  islandora:sp_large_image_collection  info:fedora/islandora:root
# 126  islandora:sp_large_image_collection  info:fedora/islandora:root
# 127  islandora:sp_large_image_collection  info:fedora/islandora:root
# 128          islandora:entity_collection  info:fedora/islandora:root
# 129          islandora:entity_collection  info:fedora/islandora:root
# 130          islandora:entity_collection  info:fedora/islandora:root
# 131          islandora:entity_collection  info:fedora/islandora:root
# 132   islandora:sp_disk_image_collection  info:fedora/islandora:root
# 133   islandora:sp_disk_image_collection  info:fedora/islandora:root
# 134   islandora:sp_disk_image_collection  info:fedora/islandora:root
# 135   islandora:sp_disk_image_collection  info:fedora/islandora:root
# 136        islandora:compound_collection  info:fedora/islandora:root
# 137        islandora:compound_collection  info:fedora/islandora:root
# 138        islandora:compound_collection  info:fedora/islandora:root
# 139        islandora:compound_collection  info:fedora/islandora:root
# 140             islandora:bookCollection  info:fedora/islandora:root
# 141             islandora:bookCollection  info:fedora/islandora:root
# 142             islandora:bookCollection  info:fedora/islandora:root
# 143             islandora:bookCollection  info:fedora/islandora:root
# 144           islandora:audio_collection  info:fedora/islandora:root
# 145           islandora:audio_collection  info:fedora/islandora:root
# 146           islandora:audio_collection  info:fedora/islandora:root
# 147           islandora:audio_collection  info:fedora/islandora:root
# 148                       islandora:root                         NaN
# 149                       islandora:root                         NaN
# 150                       islandora:root                         NaN
# 151                       islandora:root                         NaN
#
#                   isPageOf                                  cmodel  \
# 0                      NaN    info:fedora/islandora:sp_basic_image
# 1                      NaN    info:fedora/islandora:sp_basic_image
# 2                      NaN    info:fedora/islandora:sp_basic_image
# 3                      NaN    info:fedora/islandora:sp_basic_image
# 4                      NaN    info:fedora/islandora:sp_basic_image
# 5                      NaN    info:fedora/islandora:sp_basic_image
# 6                      NaN    info:fedora/islandora:sp_basic_image
# 7                      NaN    info:fedora/islandora:sp_basic_image
# 8                      NaN    info:fedora/islandora:sp_basic_image
# 9                      NaN    info:fedora/islandora:sp_basic_image
# 10                     NaN    info:fedora/islandora:sp_basic_image
# 11                     NaN    info:fedora/islandora:sp_basic_image
# 12                     NaN    info:fedora/islandora:sp_basic_image
# 13                     NaN    info:fedora/islandora:sp_basic_image
# 14                     NaN    info:fedora/islandora:sp_basic_image
# 15                     NaN    info:fedora/islandora:sp_basic_image
# 16   info:fedora/example:1        info:fedora/islandora:pageCModel
# 17   info:fedora/example:1        info:fedora/islandora:pageCModel
# 18   info:fedora/example:1        info:fedora/islandora:pageCModel
# 19   info:fedora/example:1        info:fedora/islandora:pageCModel
# 20   info:fedora/example:1        info:fedora/islandora:pageCModel
# 21   info:fedora/example:1        info:fedora/islandora:pageCModel
# 22   info:fedora/example:1        info:fedora/islandora:pageCModel
# 23   info:fedora/example:1        info:fedora/islandora:pageCModel
# 24   info:fedora/example:1        info:fedora/islandora:pageCModel
# 25   info:fedora/example:1        info:fedora/islandora:pageCModel
# 26   info:fedora/example:1        info:fedora/islandora:pageCModel
# 27   info:fedora/example:1        info:fedora/islandora:pageCModel
# 28   info:fedora/example:1        info:fedora/islandora:pageCModel
# 29   info:fedora/example:1        info:fedora/islandora:pageCModel
# ..                     ...                                     ...
# 122                    NaN  info:fedora/islandora:collectionCModel
# 123                    NaN  info:fedora/islandora:collectionCModel
# 124                    NaN  info:fedora/islandora:collectionCModel
# 125                    NaN  info:fedora/islandora:collectionCModel
# 126                    NaN  info:fedora/islandora:collectionCModel
# 127                    NaN  info:fedora/islandora:collectionCModel
# 128                    NaN  info:fedora/islandora:collectionCModel
# 129                    NaN  info:fedora/islandora:collectionCModel
# 130                    NaN  info:fedora/islandora:collectionCModel
# 131                    NaN  info:fedora/islandora:collectionCModel
# 132                    NaN  info:fedora/islandora:collectionCModel
# 133                    NaN  info:fedora/islandora:collectionCModel
# 134                    NaN  info:fedora/islandora:collectionCModel
# 135                    NaN  info:fedora/islandora:collectionCModel
# 136                    NaN  info:fedora/islandora:collectionCModel
# 137                    NaN  info:fedora/islandora:collectionCModel
# 138                    NaN  info:fedora/islandora:collectionCModel
# 139                    NaN  info:fedora/islandora:collectionCModel
# 140                    NaN  info:fedora/islandora:collectionCModel
# 141                    NaN  info:fedora/islandora:collectionCModel
# 142                    NaN  info:fedora/islandora:collectionCModel
# 143                    NaN  info:fedora/islandora:collectionCModel
# 144                    NaN  info:fedora/islandora:collectionCModel
# 145                    NaN  info:fedora/islandora:collectionCModel
# 146                    NaN  info:fedora/islandora:collectionCModel
# 147                    NaN  info:fedora/islandora:collectionCModel
# 148                    NaN  info:fedora/islandora:collectionCModel
# 149                    NaN  info:fedora/islandora:collectionCModel
# 150                    NaN  info:fedora/islandora:collectionCModel
# 151                    NaN  info:fedora/islandora:collectionCModel
#
#              datastream OBJ_Exists                              obj_checksum  \
# 0                 AUDIT        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 1              RELS-EXT        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 2                  MODS        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 3                    DC        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 4                   OBJ        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 5                TECHMD        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 6                    TN        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 7           MEDIUM_SIZE        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 8                 AUDIT        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 9              RELS-EXT        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 10                 MODS        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 11                   DC        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 12                  OBJ        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 13               TECHMD        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 14                   TN        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 15          MEDIUM_SIZE        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 16                AUDIT        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 17             RELS-EXT        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 18                  PDF        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 19                  OBJ        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 20                   DC        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 21                   TN        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 22                  JP2        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 23               TECHMD        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 24                  JPG        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 25             RELS-INT        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 26                AUDIT        OBJ  cd3b241ed4869776bb90387b51766e04b7a62151
# 27             RELS-EXT        OBJ  cd3b241ed4869776bb90387b51766e04b7a62151
# 28                  PDF        OBJ  cd3b241ed4869776bb90387b51766e04b7a62151
# 29                  OBJ        OBJ  cd3b241ed4869776bb90387b51766e04b7a62151
# ..                  ...        ...                                       ...
# 122                  TN         NO                                   not_set
# 123                  DC         NO                                   not_set
# 124            RELS-EXT         NO                                   not_set
# 125   COLLECTION_POLICY         NO                                   not_set
# 126                  TN         NO                                   not_set
# 127                  DC         NO                                   not_set
# 128            RELS-EXT         NO                                   not_set
# 129                  TN         NO                                   not_set
# 130   COLLECTION_POLICY         NO                                   not_set
# 131                  DC         NO                                   not_set
# 132            RELS-EXT         NO                                   not_set
# 133   COLLECTION_POLICY         NO                                   not_set
# 134                  TN         NO                                   not_set
# 135                  DC         NO                                   not_set
# 136            RELS-EXT         NO                                   not_set
# 137   COLLECTION_POLICY         NO                                   not_set
# 138                  TN         NO                                   not_set
# 139                  DC         NO                                   not_set
# 140            RELS-EXT         NO                                   not_set
# 141   COLLECTION_POLICY         NO                                   not_set
# 142                  TN         NO                                   not_set
# 143                  DC         NO                                   not_set
# 144            RELS-EXT         NO                                   not_set
# 145   COLLECTION_POLICY         NO                                   not_set
# 146                  TN         NO                                   not_set
# 147                  DC         NO                                   not_set
# 148            RELS-EXT         NO                                   not_set
# 149   COLLECTION_POLICY         NO                                   not_set
# 150                  TN         NO                                   not_set
# 151                  DC         NO                                   not_set
#
#       Premis_Check Last_Modified_By                               obj_format  \
# 0        Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 1        Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 2        Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 3        Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 4        Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 5        Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 6        Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 7        Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 8        Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 9        Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 10       Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 11       Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 12       Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 13       Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 14       Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 15       Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 16       Validated            admin                                TIFF EXIF
# 17       Validated            admin                                TIFF EXIF
# 18       Validated            admin                                TIFF EXIF
# 19       Validated            admin                                TIFF EXIF
# 20       Validated            admin                                TIFF EXIF
# 21       Validated            admin                                TIFF EXIF
# 22       Validated            admin                                TIFF EXIF
# 23       Validated            admin                                TIFF EXIF
# 24       Validated            admin                                TIFF EXIF
# 25       Validated            admin                                TIFF EXIF
# 26       Validated            admin                                TIFF EXIF
# 27       Validated            admin                                TIFF EXIF
# 28       Validated            admin                                TIFF EXIF
# 29       Validated            admin                                TIFF EXIF
# ..             ...              ...                                      ...
# 122  Not Validated              NaN                                      NaN
# 123  Not Validated              NaN                                      NaN
# 124  Not Validated              NaN                                      NaN
# 125  Not Validated              NaN                                      NaN
# 126  Not Validated              NaN                                      NaN
# 127  Not Validated              NaN                                      NaN
# 128  Not Validated              NaN                                      NaN
# 129  Not Validated              NaN                                      NaN
# 130  Not Validated              NaN                                      NaN
# 131  Not Validated              NaN                                      NaN
# 132  Not Validated              NaN                                      NaN
# 133  Not Validated              NaN                                      NaN
# 134  Not Validated              NaN                                      NaN
# 135  Not Validated              NaN                                      NaN
# 136  Not Validated              NaN                                      NaN
# 137  Not Validated              NaN                                      NaN
# 138  Not Validated              NaN                                      NaN
# 139  Not Validated              NaN                                      NaN
# 140  Not Validated              NaN                                      NaN
# 141  Not Validated              NaN                                      NaN
# 142  Not Validated              NaN                                      NaN
# 143  Not Validated              NaN                                      NaN
# 144  Not Validated              NaN                                      NaN
# 145  Not Validated              NaN                                      NaN
# 146  Not Validated              NaN                                      NaN
# 147  Not Validated              NaN                                      NaN
# 148  Not Validated              NaN                                      NaN
# 149  Not Validated              NaN                                      NaN
# 150  Not Validated              NaN                                      NaN
# 151  Not Validated              NaN                                      NaN
#
#                       title  \
# 0               second page
# 1               second page
# 2               second page
# 3               second page
# 4               second page
# 5               second page
# 6               second page
# 7               second page
# 8                 back page
# 9                 back page
# 10                back page
# 11                back page
# 12                back page
# 13                back page
# 14                back page
# 15                back page
# 16             sample.pdf-2
# 17             sample.pdf-2
# 18             sample.pdf-2
# 19             sample.pdf-2
# 20             sample.pdf-2
# 21             sample.pdf-2
# 22             sample.pdf-2
# 23             sample.pdf-2
# 24             sample.pdf-2
# 25             sample.pdf-2
# 26             sample.pdf-1
# 27             sample.pdf-1
# 28             sample.pdf-1
# 29             sample.pdf-1
# ..                      ...
# 122    Newspaper Collection
# 123    Newspaper Collection
# 124  Large Image Collection
# 125  Large Image Collection
# 126  Large Image Collection
# 127  Large Image Collection
# 128       Entity Collection
# 129       Entity Collection
# 130       Entity Collection
# 131       Entity Collection
# 132   Disk Image Collection
# 133   Disk Image Collection
# 134   Disk Image Collection
# 135   Disk Image Collection
# 136     Compound Collection
# 137     Compound Collection
# 138     Compound Collection
# 139     Compound Collection
# 140         Book Collection
# 141         Book Collection
# 142         Book Collection
# 143         Book Collection
# 144        Audio Collection
# 145        Audio Collection
# 146        Audio Collection
# 147        Audio Collection
# 148    Top-level Collection
# 149    Top-level Collection
# 150    Top-level Collection
# 151    Top-level Collection
#
#                                              size_list  \
# 0    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 1    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 2    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 3    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 4    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 5    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 6    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 7    not_set, 718, 1260, 454, 1878576, 3439, 29414,...
# 8    not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 9    not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 10   not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 11   not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 12   not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 13   not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 14   not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 15   not_set, 718, 1258, 452, 1878576, 3439, 29414,...
# 16   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 17   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 18   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 19   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 20   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 21   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 22   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 23   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 24   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 25   not_set, 822, 6636, 280983, 374, 188825, 13813...
# 26   not_set, 822, 6185, 298854, 374, 189257, 14929...
# 27   not_set, 822, 6185, 298854, 374, 189257, 14929...
# 28   not_set, 822, 6185, 298854, 374, 189257, 14929...
# 29   not_set, 822, 6185, 298854, 374, 189257, 14929...
# ..                                                 ...
# 122                                579, 690, 5137, 402
# 123                                579, 690, 5137, 402
# 124                                584, 535, 5137, 409
# 125                                584, 535, 5137, 409
# 126                                584, 535, 5137, 409
# 127                                584, 535, 5137, 409
# 128                                576, 5137, 936, 396
# 129                                576, 5137, 936, 396
# 130                                576, 5137, 936, 396
# 131                                576, 5137, 936, 396
# 132                                583, 528, 5137, 407
# 133                                583, 528, 5137, 407
# 134                                583, 528, 5137, 407
# 135                                583, 528, 5137, 407
# 136                                578, 726, 5137, 400
# 137                                578, 726, 5137, 400
# 138                                578, 726, 5137, 400
# 139                                578, 726, 5137, 400
# 140                               573, 1165, 5137, 391
# 141                               573, 1165, 5137, 391
# 142                               573, 1165, 5137, 391
# 143                               573, 1165, 5137, 391
# 144                                575, 510, 5137, 394
# 145                                575, 510, 5137, 394
# 146                                575, 510, 5137, 394
# 147                                575, 510, 5137, 394
# 148                               457, 1209, 5137, 386
# 149                               457, 1209, 5137, 386
# 150                               457, 1209, 5137, 386
# 151                               457, 1209, 5137, 386
#
#               fgs_lastModifiedDate_dt  namespace  \
# 0     Tuesday, March 26, 2019 - 01:05  islandora
# 1     Tuesday, March 26, 2019 - 01:05  islandora
# 2     Tuesday, March 26, 2019 - 01:05  islandora
# 3     Tuesday, March 26, 2019 - 01:05  islandora
# 4     Tuesday, March 26, 2019 - 01:05  islandora
# 5     Tuesday, March 26, 2019 - 01:05  islandora
# 6     Tuesday, March 26, 2019 - 01:05  islandora
# 7     Tuesday, March 26, 2019 - 01:05  islandora
# 8     Tuesday, March 26, 2019 - 01:05  islandora
# 9     Tuesday, March 26, 2019 - 01:05  islandora
# 10    Tuesday, March 26, 2019 - 01:05  islandora
# 11    Tuesday, March 26, 2019 - 01:05  islandora
# 12    Tuesday, March 26, 2019 - 01:05  islandora
# 13    Tuesday, March 26, 2019 - 01:05  islandora
# 14    Tuesday, March 26, 2019 - 01:05  islandora
# 15    Tuesday, March 26, 2019 - 01:05  islandora
# 16    Tuesday, March 26, 2019 - 01:05    example
# 17    Tuesday, March 26, 2019 - 01:05    example
# 18    Tuesday, March 26, 2019 - 01:05    example
# 19    Tuesday, March 26, 2019 - 01:05    example
# 20    Tuesday, March 26, 2019 - 01:05    example
# 21    Tuesday, March 26, 2019 - 01:05    example
# 22    Tuesday, March 26, 2019 - 01:05    example
# 23    Tuesday, March 26, 2019 - 01:05    example
# 24    Tuesday, March 26, 2019 - 01:05    example
# 25    Tuesday, March 26, 2019 - 01:05    example
# 26    Tuesday, March 26, 2019 - 01:05    example
# 27    Tuesday, March 26, 2019 - 01:05    example
# 28    Tuesday, March 26, 2019 - 01:05    example
# 29    Tuesday, March 26, 2019 - 01:05    example
# ..                                ...        ...
# 122  Thursday, March 21, 2019 - 16:22  islandora
# 123  Thursday, March 21, 2019 - 16:22  islandora
# 124  Thursday, March 21, 2019 - 16:22  islandora
# 125  Thursday, March 21, 2019 - 16:22  islandora
# 126  Thursday, March 21, 2019 - 16:22  islandora
# 127  Thursday, March 21, 2019 - 16:22  islandora
# 128  Thursday, March 21, 2019 - 16:22  islandora
# 129  Thursday, March 21, 2019 - 16:22  islandora
# 130  Thursday, March 21, 2019 - 16:22  islandora
# 131  Thursday, March 21, 2019 - 16:22  islandora
# 132  Thursday, March 21, 2019 - 16:22  islandora
# 133  Thursday, March 21, 2019 - 16:22  islandora
# 134  Thursday, March 21, 2019 - 16:22  islandora
# 135  Thursday, March 21, 2019 - 16:22  islandora
# 136  Thursday, March 21, 2019 - 16:22  islandora
# 137  Thursday, March 21, 2019 - 16:22  islandora
# 138  Thursday, March 21, 2019 - 16:22  islandora
# 139  Thursday, March 21, 2019 - 16:22  islandora
# 140  Thursday, March 21, 2019 - 16:22  islandora
# 141  Thursday, March 21, 2019 - 16:22  islandora
# 142  Thursday, March 21, 2019 - 16:22  islandora
# 143  Thursday, March 21, 2019 - 16:22  islandora
# 144  Thursday, March 21, 2019 - 16:22  islandora
# 145  Thursday, March 21, 2019 - 16:22  islandora
# 146  Thursday, March 21, 2019 - 16:22  islandora
# 147  Thursday, March 21, 2019 - 16:22  islandora
# 148  Thursday, March 21, 2019 - 16:22  islandora
# 149  Thursday, March 21, 2019 - 16:22  islandora
# 150  Thursday, March 21, 2019 - 16:22  islandora
# 151  Thursday, March 21, 2019 - 16:22  islandora
#
#                                       checksum              mimetype
# 0                                      not_set              text/xml
# 1     94e8f30a05c70096e53be5b1dcb6066769dbb6fd   application/rdf+xml
# 2     bafe21cbde340c0764c8313038623d10290386c6       application/xml
# 3     4ca48ca4c7ca3d9964b33485baa1e9c5510e31cf              text/xml
# 4     22ace46f16f064d6c24fe8027030907165ee9eca            image/jpeg
# 5     11d5dce7535e39645062f7f90344e46375406deb       application/xml
# 6     b595f3883e67a44971b6408f560d245e4d365c22            image/jpeg
# 7     ff33520ee0f17d2ef3f48fef72abb6472c048ccf            image/jpeg
# 8                                      not_set              text/xml
# 9     d1c419dba0ca9e133dcdd478ad654b728e1f76c5   application/rdf+xml
# 10    77a56f5e37d770ad1c00da0530c8114c6367721d       application/xml
# 11    419f2767e466c2333f4cf841826f71c7460e66b0              text/xml
# 12    22ace46f16f064d6c24fe8027030907165ee9eca            image/jpeg
# 13    7b4df65213ff1a5b66ac85475c5a919b0cdd0534       application/xml
# 14    b595f3883e67a44971b6408f560d245e4d365c22            image/jpeg
# 15    ff33520ee0f17d2ef3f48fef72abb6472c048ccf            image/jpeg
# 16                                     not_set              text/xml
# 17    3092d6667f455f236e48a737b1cbd12cbe17a675   application/rdf+xml
# 18    1b1d13ad38eb128e1e83fb22dd00f87d977665b5       application/pdf
# 19    2aff5cfebf859d7933ee76bba594b1ede8e30f9e            image/tiff
# 20                                     not_set              text/xml
# 21    4dc07e63bfa2c3391759f117788cd3026911dcc1            image/jpeg
# 22    79a1d450bef92073283ad3505781ac2fd6d75250             image/jp2
# 23    bfca439bbeed45f7107a8095bbd8b41ac9b567e3       application/xml
# 24    202deb5896e35a79cde0d6bc8e096e13cd08d9c4            image/jpeg
# 25    d9ce3442823d090008f604e71a64f8c0cb8a8751   application/rdf+xml
# 26                                     not_set              text/xml
# 27    0b34e4584546dc42ef0f0209ca1105ce87cc7af0   application/rdf+xml
# 28    e066feea58b0227c24509c192dbbc4be66f49657       application/pdf
# 29    cd3b241ed4869776bb90387b51766e04b7a62151            image/tiff
# ..                                         ...                   ...
# 122                                    not_set             image/png
# 123                                    not_set              text/xml
# 124                                    not_set   application/rdf+xml
# 125                                    not_set       application/xml
# 126                                    not_set             image/png
# 127                                    not_set              text/xml
# 128                                    not_set   application/rdf+xml
# 129                                    not_set             image/png
# 130                                    not_set              text/xml
# 131                                    not_set              text/xml
# 132                                    not_set   application/rdf+xml
# 133                                    not_set       application/xml
# 134                                    not_set             image/png
# 135                                    not_set              text/xml
# 136                                    not_set   application/rdf+xml
# 137                                    not_set       application/xml
# 138                                    not_set             image/png
# 139                                    not_set              text/xml
# 140                                    not_set   application/rdf+xml
# 141                                    not_set       application/xml
# 142                                    not_set             image/png
# 143                                    not_set              text/xml
# 144                                    not_set   application/rdf+xml
# 145                                    not_set       application/xml
# 146                                    not_set             image/png
# 147                                    not_set              text/xml
# 148                                    not_set   application/rdf+xml
# 149                                    not_set       application/xml
# 150                                    not_set             image/png
# 151                                    not_set              text/xml
#
# [152 rows x 16 columns]

# %%
df_size = \
(df.set_index(df.columns.drop('size_list',1).tolist())
   .size_list.str.split(',', expand=True)
   .stack()
   .reset_index()
   .rename(columns={0:'size_list'})
   .loc[:, df.columns]
)

# %%
del df_ds["size_list"]
df_ds["size"] = df_size.size_list

# %%
df_ds
# Out:
#                                      PID        isMemberOfCollection  \
# 0                           islandora:11     info:fedora/example:nat
# 1                           islandora:11     info:fedora/example:nat
# 2                           islandora:11     info:fedora/example:nat
# 3                           islandora:11     info:fedora/example:nat
# 4                           islandora:11     info:fedora/example:nat
# 5                           islandora:11     info:fedora/example:nat
# 6                           islandora:11     info:fedora/example:nat
# 7                           islandora:11     info:fedora/example:nat
# 8                           islandora:10     info:fedora/example:nat
# 9                           islandora:10     info:fedora/example:nat
# 10                          islandora:10     info:fedora/example:nat
# 11                          islandora:10     info:fedora/example:nat
# 12                          islandora:10     info:fedora/example:nat
# 13                          islandora:10     info:fedora/example:nat
# 14                          islandora:10     info:fedora/example:nat
# 15                          islandora:10     info:fedora/example:nat
# 16                             example:3                         NaN
# 17                             example:3                         NaN
# 18                             example:3                         NaN
# 19                             example:3                         NaN
# 20                             example:3                         NaN
# 21                             example:3                         NaN
# 22                             example:3                         NaN
# 23                             example:3                         NaN
# 24                             example:3                         NaN
# 25                             example:3                         NaN
# 26                             example:2                         NaN
# 27                             example:2                         NaN
# 28                             example:2                         NaN
# 29                             example:2                         NaN
# ..                                   ...                         ...
# 122       islandora:newspaper_collection  info:fedora/islandora:root
# 123       islandora:newspaper_collection  info:fedora/islandora:root
# 124  islandora:sp_large_image_collection  info:fedora/islandora:root
# 125  islandora:sp_large_image_collection  info:fedora/islandora:root
# 126  islandora:sp_large_image_collection  info:fedora/islandora:root
# 127  islandora:sp_large_image_collection  info:fedora/islandora:root
# 128          islandora:entity_collection  info:fedora/islandora:root
# 129          islandora:entity_collection  info:fedora/islandora:root
# 130          islandora:entity_collection  info:fedora/islandora:root
# 131          islandora:entity_collection  info:fedora/islandora:root
# 132   islandora:sp_disk_image_collection  info:fedora/islandora:root
# 133   islandora:sp_disk_image_collection  info:fedora/islandora:root
# 134   islandora:sp_disk_image_collection  info:fedora/islandora:root
# 135   islandora:sp_disk_image_collection  info:fedora/islandora:root
# 136        islandora:compound_collection  info:fedora/islandora:root
# 137        islandora:compound_collection  info:fedora/islandora:root
# 138        islandora:compound_collection  info:fedora/islandora:root
# 139        islandora:compound_collection  info:fedora/islandora:root
# 140             islandora:bookCollection  info:fedora/islandora:root
# 141             islandora:bookCollection  info:fedora/islandora:root
# 142             islandora:bookCollection  info:fedora/islandora:root
# 143             islandora:bookCollection  info:fedora/islandora:root
# 144           islandora:audio_collection  info:fedora/islandora:root
# 145           islandora:audio_collection  info:fedora/islandora:root
# 146           islandora:audio_collection  info:fedora/islandora:root
# 147           islandora:audio_collection  info:fedora/islandora:root
# 148                       islandora:root                         NaN
# 149                       islandora:root                         NaN
# 150                       islandora:root                         NaN
# 151                       islandora:root                         NaN
#
#                   isPageOf                                  cmodel  \
# 0                      NaN    info:fedora/islandora:sp_basic_image
# 1                      NaN    info:fedora/islandora:sp_basic_image
# 2                      NaN    info:fedora/islandora:sp_basic_image
# 3                      NaN    info:fedora/islandora:sp_basic_image
# 4                      NaN    info:fedora/islandora:sp_basic_image
# 5                      NaN    info:fedora/islandora:sp_basic_image
# 6                      NaN    info:fedora/islandora:sp_basic_image
# 7                      NaN    info:fedora/islandora:sp_basic_image
# 8                      NaN    info:fedora/islandora:sp_basic_image
# 9                      NaN    info:fedora/islandora:sp_basic_image
# 10                     NaN    info:fedora/islandora:sp_basic_image
# 11                     NaN    info:fedora/islandora:sp_basic_image
# 12                     NaN    info:fedora/islandora:sp_basic_image
# 13                     NaN    info:fedora/islandora:sp_basic_image
# 14                     NaN    info:fedora/islandora:sp_basic_image
# 15                     NaN    info:fedora/islandora:sp_basic_image
# 16   info:fedora/example:1        info:fedora/islandora:pageCModel
# 17   info:fedora/example:1        info:fedora/islandora:pageCModel
# 18   info:fedora/example:1        info:fedora/islandora:pageCModel
# 19   info:fedora/example:1        info:fedora/islandora:pageCModel
# 20   info:fedora/example:1        info:fedora/islandora:pageCModel
# 21   info:fedora/example:1        info:fedora/islandora:pageCModel
# 22   info:fedora/example:1        info:fedora/islandora:pageCModel
# 23   info:fedora/example:1        info:fedora/islandora:pageCModel
# 24   info:fedora/example:1        info:fedora/islandora:pageCModel
# 25   info:fedora/example:1        info:fedora/islandora:pageCModel
# 26   info:fedora/example:1        info:fedora/islandora:pageCModel
# 27   info:fedora/example:1        info:fedora/islandora:pageCModel
# 28   info:fedora/example:1        info:fedora/islandora:pageCModel
# 29   info:fedora/example:1        info:fedora/islandora:pageCModel
# ..                     ...                                     ...
# 122                    NaN  info:fedora/islandora:collectionCModel
# 123                    NaN  info:fedora/islandora:collectionCModel
# 124                    NaN  info:fedora/islandora:collectionCModel
# 125                    NaN  info:fedora/islandora:collectionCModel
# 126                    NaN  info:fedora/islandora:collectionCModel
# 127                    NaN  info:fedora/islandora:collectionCModel
# 128                    NaN  info:fedora/islandora:collectionCModel
# 129                    NaN  info:fedora/islandora:collectionCModel
# 130                    NaN  info:fedora/islandora:collectionCModel
# 131                    NaN  info:fedora/islandora:collectionCModel
# 132                    NaN  info:fedora/islandora:collectionCModel
# 133                    NaN  info:fedora/islandora:collectionCModel
# 134                    NaN  info:fedora/islandora:collectionCModel
# 135                    NaN  info:fedora/islandora:collectionCModel
# 136                    NaN  info:fedora/islandora:collectionCModel
# 137                    NaN  info:fedora/islandora:collectionCModel
# 138                    NaN  info:fedora/islandora:collectionCModel
# 139                    NaN  info:fedora/islandora:collectionCModel
# 140                    NaN  info:fedora/islandora:collectionCModel
# 141                    NaN  info:fedora/islandora:collectionCModel
# 142                    NaN  info:fedora/islandora:collectionCModel
# 143                    NaN  info:fedora/islandora:collectionCModel
# 144                    NaN  info:fedora/islandora:collectionCModel
# 145                    NaN  info:fedora/islandora:collectionCModel
# 146                    NaN  info:fedora/islandora:collectionCModel
# 147                    NaN  info:fedora/islandora:collectionCModel
# 148                    NaN  info:fedora/islandora:collectionCModel
# 149                    NaN  info:fedora/islandora:collectionCModel
# 150                    NaN  info:fedora/islandora:collectionCModel
# 151                    NaN  info:fedora/islandora:collectionCModel
#
#              datastream OBJ_Exists                              obj_checksum  \
# 0                 AUDIT        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 1              RELS-EXT        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 2                  MODS        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 3                    DC        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 4                   OBJ        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 5                TECHMD        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 6                    TN        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 7           MEDIUM_SIZE        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 8                 AUDIT        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 9              RELS-EXT        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 10                 MODS        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 11                   DC        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 12                  OBJ        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 13               TECHMD        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 14                   TN        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 15          MEDIUM_SIZE        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca
# 16                AUDIT        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 17             RELS-EXT        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 18                  PDF        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 19                  OBJ        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 20                   DC        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 21                   TN        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 22                  JP2        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 23               TECHMD        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 24                  JPG        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 25             RELS-INT        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e
# 26                AUDIT        OBJ  cd3b241ed4869776bb90387b51766e04b7a62151
# 27             RELS-EXT        OBJ  cd3b241ed4869776bb90387b51766e04b7a62151
# 28                  PDF        OBJ  cd3b241ed4869776bb90387b51766e04b7a62151
# 29                  OBJ        OBJ  cd3b241ed4869776bb90387b51766e04b7a62151
# ..                  ...        ...                                       ...
# 122                  TN         NO                                   not_set
# 123                  DC         NO                                   not_set
# 124            RELS-EXT         NO                                   not_set
# 125   COLLECTION_POLICY         NO                                   not_set
# 126                  TN         NO                                   not_set
# 127                  DC         NO                                   not_set
# 128            RELS-EXT         NO                                   not_set
# 129                  TN         NO                                   not_set
# 130   COLLECTION_POLICY         NO                                   not_set
# 131                  DC         NO                                   not_set
# 132            RELS-EXT         NO                                   not_set
# 133   COLLECTION_POLICY         NO                                   not_set
# 134                  TN         NO                                   not_set
# 135                  DC         NO                                   not_set
# 136            RELS-EXT         NO                                   not_set
# 137   COLLECTION_POLICY         NO                                   not_set
# 138                  TN         NO                                   not_set
# 139                  DC         NO                                   not_set
# 140            RELS-EXT         NO                                   not_set
# 141   COLLECTION_POLICY         NO                                   not_set
# 142                  TN         NO                                   not_set
# 143                  DC         NO                                   not_set
# 144            RELS-EXT         NO                                   not_set
# 145   COLLECTION_POLICY         NO                                   not_set
# 146                  TN         NO                                   not_set
# 147                  DC         NO                                   not_set
# 148            RELS-EXT         NO                                   not_set
# 149   COLLECTION_POLICY         NO                                   not_set
# 150                  TN         NO                                   not_set
# 151                  DC         NO                                   not_set
#
#       Premis_Check Last_Modified_By                               obj_format  \
# 0        Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 1        Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 2        Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 3        Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 4        Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 5        Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 6        Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 7        Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 8        Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 9        Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 10       Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 11       Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 12       Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 13       Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 14       Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 15       Validated            admin  JPEG File Interchange Format, JPEG EXIF
# 16       Validated            admin                                TIFF EXIF
# 17       Validated            admin                                TIFF EXIF
# 18       Validated            admin                                TIFF EXIF
# 19       Validated            admin                                TIFF EXIF
# 20       Validated            admin                                TIFF EXIF
# 21       Validated            admin                                TIFF EXIF
# 22       Validated            admin                                TIFF EXIF
# 23       Validated            admin                                TIFF EXIF
# 24       Validated            admin                                TIFF EXIF
# 25       Validated            admin                                TIFF EXIF
# 26       Validated            admin                                TIFF EXIF
# 27       Validated            admin                                TIFF EXIF
# 28       Validated            admin                                TIFF EXIF
# 29       Validated            admin                                TIFF EXIF
# ..             ...              ...                                      ...
# 122  Not Validated              NaN                                      NaN
# 123  Not Validated              NaN                                      NaN
# 124  Not Validated              NaN                                      NaN
# 125  Not Validated              NaN                                      NaN
# 126  Not Validated              NaN                                      NaN
# 127  Not Validated              NaN                                      NaN
# 128  Not Validated              NaN                                      NaN
# 129  Not Validated              NaN                                      NaN
# 130  Not Validated              NaN                                      NaN
# 131  Not Validated              NaN                                      NaN
# 132  Not Validated              NaN                                      NaN
# 133  Not Validated              NaN                                      NaN
# 134  Not Validated              NaN                                      NaN
# 135  Not Validated              NaN                                      NaN
# 136  Not Validated              NaN                                      NaN
# 137  Not Validated              NaN                                      NaN
# 138  Not Validated              NaN                                      NaN
# 139  Not Validated              NaN                                      NaN
# 140  Not Validated              NaN                                      NaN
# 141  Not Validated              NaN                                      NaN
# 142  Not Validated              NaN                                      NaN
# 143  Not Validated              NaN                                      NaN
# 144  Not Validated              NaN                                      NaN
# 145  Not Validated              NaN                                      NaN
# 146  Not Validated              NaN                                      NaN
# 147  Not Validated              NaN                                      NaN
# 148  Not Validated              NaN                                      NaN
# 149  Not Validated              NaN                                      NaN
# 150  Not Validated              NaN                                      NaN
# 151  Not Validated              NaN                                      NaN
#
#                       title           fgs_lastModifiedDate_dt  namespace  \
# 0               second page   Tuesday, March 26, 2019 - 01:05  islandora
# 1               second page   Tuesday, March 26, 2019 - 01:05  islandora
# 2               second page   Tuesday, March 26, 2019 - 01:05  islandora
# 3               second page   Tuesday, March 26, 2019 - 01:05  islandora
# 4               second page   Tuesday, March 26, 2019 - 01:05  islandora
# 5               second page   Tuesday, March 26, 2019 - 01:05  islandora
# 6               second page   Tuesday, March 26, 2019 - 01:05  islandora
# 7               second page   Tuesday, March 26, 2019 - 01:05  islandora
# 8                 back page   Tuesday, March 26, 2019 - 01:05  islandora
# 9                 back page   Tuesday, March 26, 2019 - 01:05  islandora
# 10                back page   Tuesday, March 26, 2019 - 01:05  islandora
# 11                back page   Tuesday, March 26, 2019 - 01:05  islandora
# 12                back page   Tuesday, March 26, 2019 - 01:05  islandora
# 13                back page   Tuesday, March 26, 2019 - 01:05  islandora
# 14                back page   Tuesday, March 26, 2019 - 01:05  islandora
# 15                back page   Tuesday, March 26, 2019 - 01:05  islandora
# 16             sample.pdf-2   Tuesday, March 26, 2019 - 01:05    example
# 17             sample.pdf-2   Tuesday, March 26, 2019 - 01:05    example
# 18             sample.pdf-2   Tuesday, March 26, 2019 - 01:05    example
# 19             sample.pdf-2   Tuesday, March 26, 2019 - 01:05    example
# 20             sample.pdf-2   Tuesday, March 26, 2019 - 01:05    example
# 21             sample.pdf-2   Tuesday, March 26, 2019 - 01:05    example
# 22             sample.pdf-2   Tuesday, March 26, 2019 - 01:05    example
# 23             sample.pdf-2   Tuesday, March 26, 2019 - 01:05    example
# 24             sample.pdf-2   Tuesday, March 26, 2019 - 01:05    example
# 25             sample.pdf-2   Tuesday, March 26, 2019 - 01:05    example
# 26             sample.pdf-1   Tuesday, March 26, 2019 - 01:05    example
# 27             sample.pdf-1   Tuesday, March 26, 2019 - 01:05    example
# 28             sample.pdf-1   Tuesday, March 26, 2019 - 01:05    example
# 29             sample.pdf-1   Tuesday, March 26, 2019 - 01:05    example
# ..                      ...                               ...        ...
# 122    Newspaper Collection  Thursday, March 21, 2019 - 16:22  islandora
# 123    Newspaper Collection  Thursday, March 21, 2019 - 16:22  islandora
# 124  Large Image Collection  Thursday, March 21, 2019 - 16:22  islandora
# 125  Large Image Collection  Thursday, March 21, 2019 - 16:22  islandora
# 126  Large Image Collection  Thursday, March 21, 2019 - 16:22  islandora
# 127  Large Image Collection  Thursday, March 21, 2019 - 16:22  islandora
# 128       Entity Collection  Thursday, March 21, 2019 - 16:22  islandora
# 129       Entity Collection  Thursday, March 21, 2019 - 16:22  islandora
# 130       Entity Collection  Thursday, March 21, 2019 - 16:22  islandora
# 131       Entity Collection  Thursday, March 21, 2019 - 16:22  islandora
# 132   Disk Image Collection  Thursday, March 21, 2019 - 16:22  islandora
# 133   Disk Image Collection  Thursday, March 21, 2019 - 16:22  islandora
# 134   Disk Image Collection  Thursday, March 21, 2019 - 16:22  islandora
# 135   Disk Image Collection  Thursday, March 21, 2019 - 16:22  islandora
# 136     Compound Collection  Thursday, March 21, 2019 - 16:22  islandora
# 137     Compound Collection  Thursday, March 21, 2019 - 16:22  islandora
# 138     Compound Collection  Thursday, March 21, 2019 - 16:22  islandora
# 139     Compound Collection  Thursday, March 21, 2019 - 16:22  islandora
# 140         Book Collection  Thursday, March 21, 2019 - 16:22  islandora
# 141         Book Collection  Thursday, March 21, 2019 - 16:22  islandora
# 142         Book Collection  Thursday, March 21, 2019 - 16:22  islandora
# 143         Book Collection  Thursday, March 21, 2019 - 16:22  islandora
# 144        Audio Collection  Thursday, March 21, 2019 - 16:22  islandora
# 145        Audio Collection  Thursday, March 21, 2019 - 16:22  islandora
# 146        Audio Collection  Thursday, March 21, 2019 - 16:22  islandora
# 147        Audio Collection  Thursday, March 21, 2019 - 16:22  islandora
# 148    Top-level Collection  Thursday, March 21, 2019 - 16:22  islandora
# 149    Top-level Collection  Thursday, March 21, 2019 - 16:22  islandora
# 150    Top-level Collection  Thursday, March 21, 2019 - 16:22  islandora
# 151    Top-level Collection  Thursday, March 21, 2019 - 16:22  islandora
#
#                                       checksum              mimetype      size
# 0                                      not_set              text/xml   not_set
# 1     94e8f30a05c70096e53be5b1dcb6066769dbb6fd   application/rdf+xml       718
# 2     bafe21cbde340c0764c8313038623d10290386c6       application/xml      1260
# 3     4ca48ca4c7ca3d9964b33485baa1e9c5510e31cf              text/xml       454
# 4     22ace46f16f064d6c24fe8027030907165ee9eca            image/jpeg   1878576
# 5     11d5dce7535e39645062f7f90344e46375406deb       application/xml      3439
# 6     b595f3883e67a44971b6408f560d245e4d365c22            image/jpeg     29414
# 7     ff33520ee0f17d2ef3f48fef72abb6472c048ccf            image/jpeg     59800
# 8                                      not_set              text/xml   not_set
# 9     d1c419dba0ca9e133dcdd478ad654b728e1f76c5   application/rdf+xml       718
# 10    77a56f5e37d770ad1c00da0530c8114c6367721d       application/xml      1258
# 11    419f2767e466c2333f4cf841826f71c7460e66b0              text/xml       452
# 12    22ace46f16f064d6c24fe8027030907165ee9eca            image/jpeg   1878576
# 13    7b4df65213ff1a5b66ac85475c5a919b0cdd0534       application/xml      3439
# 14    b595f3883e67a44971b6408f560d245e4d365c22            image/jpeg     29414
# 15    ff33520ee0f17d2ef3f48fef72abb6472c048ccf            image/jpeg     59800
# 16                                     not_set              text/xml   not_set
# 17    3092d6667f455f236e48a737b1cbd12cbe17a675   application/rdf+xml       822
# 18    1b1d13ad38eb128e1e83fb22dd00f87d977665b5       application/pdf      6636
# 19    2aff5cfebf859d7933ee76bba594b1ede8e30f9e            image/tiff    280983
# 20                                     not_set              text/xml       374
# 21    4dc07e63bfa2c3391759f117788cd3026911dcc1            image/jpeg    188825
# 22    79a1d450bef92073283ad3505781ac2fd6d75250             image/jp2    138130
# 23    bfca439bbeed45f7107a8095bbd8b41ac9b567e3       application/xml      6478
# 24    202deb5896e35a79cde0d6bc8e096e13cd08d9c4            image/jpeg    237440
# 25    d9ce3442823d090008f604e71a64f8c0cb8a8751   application/rdf+xml       355
# 26                                     not_set              text/xml   not_set
# 27    0b34e4584546dc42ef0f0209ca1105ce87cc7af0   application/rdf+xml       822
# 28    e066feea58b0227c24509c192dbbc4be66f49657       application/pdf      6185
# 29    cd3b241ed4869776bb90387b51766e04b7a62151            image/tiff    298854
# ..                                         ...                   ...       ...
# 122                                    not_set             image/png      5137
# 123                                    not_set              text/xml       402
# 124                                    not_set   application/rdf+xml       584
# 125                                    not_set       application/xml       535
# 126                                    not_set             image/png      5137
# 127                                    not_set              text/xml       409
# 128                                    not_set   application/rdf+xml       576
# 129                                    not_set             image/png      5137
# 130                                    not_set              text/xml       936
# 131                                    not_set              text/xml       396
# 132                                    not_set   application/rdf+xml       583
# 133                                    not_set       application/xml       528
# 134                                    not_set             image/png      5137
# 135                                    not_set              text/xml       407
# 136                                    not_set   application/rdf+xml       578
# 137                                    not_set       application/xml       726
# 138                                    not_set             image/png      5137
# 139                                    not_set              text/xml       400
# 140                                    not_set   application/rdf+xml       573
# 141                                    not_set       application/xml      1165
# 142                                    not_set             image/png      5137
# 143                                    not_set              text/xml       391
# 144                                    not_set   application/rdf+xml       575
# 145                                    not_set       application/xml       510
# 146                                    not_set             image/png      5137
# 147                                    not_set              text/xml       394
# 148                                    not_set   application/rdf+xml       457
# 149                                    not_set       application/xml      1209
# 150                                    not_set             image/png      5137
# 151                                    not_set              text/xml       386
#
# [152 rows x 16 columns]

# %%
df_ds.to_csv("reports/all_datastreams.csv")

# %%
df_ds['datastream'] = df_ds['datastream'].str.strip()
is_obj =  df_ds['datastream'] == "OBJ"
objs = df_ds[is_obj]
objs
# Out:
#              PID                             isMemberOfCollection  \
# 4   islandora:11                          info:fedora/example:nat
# 12  islandora:10                          info:fedora/example:nat
# 19     example:3                                              NaN
# 29     example:2                                              NaN
# 40   islandora:8                     info:fedora/utsc:collection2
# 48   islandora:6                          info:fedora/example:nat
# 56   islandora:5                          info:fedora/example:nat
# 64   islandora:2  info:fedora/islandora:sp_basic_image_collection
# 72   islandora:1  info:fedora/islandora:sp_basic_image_collection
#
#                  isPageOf                                cmodel datastream  \
# 4                     NaN  info:fedora/islandora:sp_basic_image        OBJ
# 12                    NaN  info:fedora/islandora:sp_basic_image        OBJ
# 19  info:fedora/example:1      info:fedora/islandora:pageCModel        OBJ
# 29  info:fedora/example:1      info:fedora/islandora:pageCModel        OBJ
# 40                    NaN  info:fedora/islandora:sp_basic_image        OBJ
# 48                    NaN  info:fedora/islandora:sp_basic_image        OBJ
# 56                    NaN  info:fedora/islandora:sp_basic_image        OBJ
# 64                    NaN  info:fedora/islandora:sp_basic_image        OBJ
# 72                    NaN  info:fedora/islandora:sp_basic_image        OBJ
#
#    OBJ_Exists                              obj_checksum Premis_Check  \
# 4         OBJ  22ace46f16f064d6c24fe8027030907165ee9eca    Validated
# 12        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca    Validated
# 19        OBJ  2aff5cfebf859d7933ee76bba594b1ede8e30f9e    Validated
# 29        OBJ  cd3b241ed4869776bb90387b51766e04b7a62151    Validated
# 40        OBJ  f4e806111bdb1c39c1e281e342afd59fed40d198    Validated
# 48        OBJ  4784c50df21ca2fa8f2a3219adcaf9dbbffe7ae8    Validated
# 56        OBJ  4e424da322f285aa179caec35397d161ab76c075    Validated
# 64        OBJ  22ace46f16f064d6c24fe8027030907165ee9eca    Validated
# 72        OBJ  f4e806111bdb1c39c1e281e342afd59fed40d198    Validated
#
#    Last_Modified_By                               obj_format            title  \
# 4             admin  JPEG File Interchange Format, JPEG EXIF      second page
# 12            admin  JPEG File Interchange Format, JPEG EXIF        back page
# 19            admin                                TIFF EXIF     sample.pdf-2
# 29            admin                                TIFF EXIF     sample.pdf-1
# 40            admin                                JPEG EXIF             aaaa
# 48            admin                                JPEG EXIF  inside object 2
# 56            admin                                JPEG EXIF  inside object 1
# 64            admin  JPEG File Interchange Format, JPEG EXIF            22222
# 72            admin                                JPEG EXIF      88888888888
#
#             fgs_lastModifiedDate_dt  namespace  \
# 4   Tuesday, March 26, 2019 - 01:05  islandora
# 12  Tuesday, March 26, 2019 - 01:05  islandora
# 19  Tuesday, March 26, 2019 - 01:05    example
# 29  Tuesday, March 26, 2019 - 01:05    example
# 40  Tuesday, March 26, 2019 - 01:05  islandora
# 48  Tuesday, March 26, 2019 - 01:05  islandora
# 56  Tuesday, March 26, 2019 - 01:05  islandora
# 64  Tuesday, March 26, 2019 - 01:05  islandora
# 72  Tuesday, March 26, 2019 - 01:05  islandora
#
#                                      checksum     mimetype      size
# 4    22ace46f16f064d6c24fe8027030907165ee9eca   image/jpeg   1878576
# 12   22ace46f16f064d6c24fe8027030907165ee9eca   image/jpeg   1878576
# 19   2aff5cfebf859d7933ee76bba594b1ede8e30f9e   image/tiff    280983
# 29   cd3b241ed4869776bb90387b51766e04b7a62151   image/tiff    298854
# 40   f4e806111bdb1c39c1e281e342afd59fed40d198   image/jpeg   3773963
# 48   4784c50df21ca2fa8f2a3219adcaf9dbbffe7ae8   image/jpeg   9041285
# 56   4e424da322f285aa179caec35397d161ab76c075   image/jpeg   9240579
# 64   22ace46f16f064d6c24fe8027030907165ee9eca   image/jpeg   1878576
# 72   f4e806111bdb1c39c1e281e342afd59fed40d198   image/jpeg   3773963

# %%
# Get total size of total OBJ objects (latest version)
objs = objs.astype({"size": int})
objs["size"].sum()
# Out:
# 32045355

# %%
# Get file formats
df_file_formats = df.groupby('obj_format')["PID"].count().reset_index(name="count")

# %%
df_file_formats.to_csv("reports/objs_by_fileformats.csv")
